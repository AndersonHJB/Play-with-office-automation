# %%
import xlsxwriter
import random
from faker import Faker
import datetime
wb = xlsxwriter.Workbook("一万个好员工信息.xlsx")
sheet = wb.add_worksheet('Sheet1')

# %%
headings = ['name','gender','join-year','join-month','department','job','job-name','company']
sheet.write_row('A1',headings)
# Out:
# 0

# %%
fake = Faker("zh_CN")
print(fake.name())
print(fake.company())
print('男' if fake.boolean() else '女')
print(random.choice(range(2001,2020)))
# Out:
# 靳莉
# 立信电子传媒有限公司
# 男
# 2005

# %%
department_info = {
    '财务':['出纳','会计'],
    '开发':['平台开发','后端开发','前端开发'],
    '测试':['黑盒测试','白盒测试'],
    '运维':['数据库运维','服务器管理'],
    '运营':['新媒体运营','传统运营'],
    '设计':['原画','插画'],
    '管理':['公司领导','技术领导'],
}

# %%
fake = Faker("zh_CN")
for i in range(2,10002):
    name = fake.name()
    gender = '男' if fake.boolean() else '女'
    
    join_year = random.choice(range(2001,2020))
    join_month = random.choice(range(1,13))
    
    department = random.choice(list(department_info.keys()))
    job = random.choice(department_info[department])
    job_name = random.choice(['初级','中级','高级','特聘']) + job
    
    company = fake.company()
    
    #today_datetime = datetime.datetime.now()
    #year = today_datetime.year
    #month = today_datetime.month
    #day = today_datetime.day
    
    line_data= [name,gender,join_year,join_month,department,job,job_name,company]
    #line_data= [name,gender,join_year,join_month,department,job,job_name,company, year,month,day]
    print(line_data)
    sheet.write_row('A{}'.format(i), line_data)
# Out:
# ['俞雪梅', '男', 2002, 4, '设计', '原画', '初级原画', '艾提科信信息有限公司']
# ['麦辉', '女', 2010, 3, '财务', '会计', '特聘会计', '图龙信息传媒有限公司']
# ['李俊', '女', 2013, 11, '测试', '白盒测试', '特聘白盒测试', '快讯网络有限公司']
# ['吴桂花', '男', 2019, 3, '管理', '公司领导', '中级公司领导', '图龙信息信息有限公司']
# ['唐璐', '女', 2010, 3, '测试', '白盒测试', '高级白盒测试', '良诺信息有限公司']
# ['杨阳', '男', 2016, 6, '测试', '白盒测试', '中级白盒测试', '飞海科技信息有限公司']
# ['钟敏', '男', 2006, 3, '运营', '新媒体运营', '特聘新媒体运营', '泰麒麟科技有限公司']
# ['王玉', '男', 2016, 8, '设计', '原画', '特聘原画', '昊嘉网络有限公司']
# ['李晶', '男', 2002, 2, '测试', '黑盒测试', '初级黑盒测试', '网新恒天科技有限公司']
# ['邓洁', '女', 2011, 12, '管理', '公司领导', '特聘公司领导', '时刻信息有限公司']
# ['张建国', '女', 2011, 4, '财务', '会计', '初级会计', '易动力信息有限公司']
# ['张华', '男', 2019, 11, '运维', '数据库运维', '特聘数据库运维', '凌云网络有限公司']
# ['陈艳', '女', 2010, 7, '开发', '后端开发', '中级后端开发', '联软传媒有限公司']
# ['许玉梅', '女', 2004, 12, '测试', '黑盒测试', '高级黑盒测试', '昊嘉信息有限公司']
# ['李淑珍', '女', 2015, 4, '开发', '后端开发', '中级后端开发', '盟新信息有限公司']
# ['王明', '男', 2008, 10, '运维', '数据库运维', '高级数据库运维', '联软网络有限公司']
# ['杨欣', '女', 2004, 7, '设计', '原画', '高级原画', '明腾网络有限公司']
# ['张桂花', '男', 2015, 4, '管理', '技术领导', '初级技术领导', '迪摩网络有限公司']
# ['王冬梅', '女', 2001, 8, '运营', '传统运营', '初级传统运营', '双敏电子传媒有限公司']
# ['刘建', '女', 2006, 7, '运维', '数据库运维', '中级数据库运维', '凌颖信息科技有限公司']
# ['吴旭', '男', 2004, 4, '财务', '会计', '中级会计', '济南亿次元信息有限公司']
# ['张平', '女', 2014, 10, '开发', '后端开发', '特聘后端开发', '数字100网络有限公司']
# ['李楠', '女', 2011, 11, '运维', '服务器管理', '特聘服务器管理', '菊风公司科技有限公司']
# ['张倩', '男', 2011, 2, '运维', '服务器管理', '特聘服务器管理', '盟新传媒有限公司']
# ['李丽', '男', 2008, 9, '运营', '传统运营', '高级传统运营', '七喜传媒有限公司']
# ['阙芳', '女', 2011, 8, '运营', '新媒体运营', '初级新媒体运营', '快讯科技有限公司']
# ['江凤兰', '男', 2007, 6, '财务', '出纳', '中级出纳', '万迅电脑信息有限公司']
# ['杭飞', '男', 2007, 9, '运营', '传统运营', '初级传统运营', '襄樊地球村网络有限公司']
# ['杨洋', '男', 2007, 1, '管理', '技术领导', '初级技术领导', '商软冠联信息有限公司']
# ['罗秀荣', '女', 2014, 11, '财务', '出纳', '特聘出纳', '银嘉科技有限公司']
# ['王浩', '男', 2006, 1, '测试', '黑盒测试', '中级黑盒测试', '中建创业网络有限公司']
# ['顾桂芳', '女', 2018, 4, '运营', '新媒体运营', '高级新媒体运营', '襄樊地球村网络有限公司']
# ['郭璐', '女', 2014, 1, '运营', '新媒体运营', '中级新媒体运营', '佳禾传媒有限公司']
# ['赵冬梅', '男', 2009, 4, '测试', '白盒测试', '初级白盒测试', '恩悌传媒有限公司']
# ['邓玉兰', '女', 2009, 12, '管理', '技术领导', '特聘技术领导', '晖来计算机信息有限公司']
# ['姜建国', '男', 2019, 4, '运维', '数据库运维', '特聘数据库运维', '鑫博腾飞信息有限公司']
# ['郭丽娟', '男', 2003, 3, '开发', '前端开发', '特聘前端开发', '巨奥传媒有限公司']
# ['蔡瑜', '男', 2012, 12, '测试', '白盒测试', '初级白盒测试', '华成育卓传媒有限公司']
# ['庄伟', '男', 2005, 12, '财务', '出纳', '特聘出纳', '国讯传媒有限公司']
# ['马岩', '女', 2012, 5, '运营', '传统运营', '初级传统运营', '四通网络有限公司']
# ['梁旭', '女', 2007, 4, '开发', '后端开发', '初级后端开发', '鸿睿思博传媒有限公司']
# ['宋荣', '女', 2011, 1, '运维', '数据库运维', '中级数据库运维', '通际名联传媒有限公司']
# ['武帆', '女', 2001, 1, '开发', '后端开发', '初级后端开发', '同兴万点传媒有限公司']
# ['郑桂荣', '男', 2014, 3, '运维', '数据库运维', '高级数据库运维', '方正科技科技有限公司']
# ['李峰', '男', 2012, 9, '开发', '前端开发', '高级前端开发', '凌云网络有限公司']
# ['李淑珍', '女', 2019, 3, '管理', '技术领导', '高级技术领导', '华成育卓科技有限公司']
# ['万建', '女', 2015, 7, '设计', '插画', '高级插画', '良诺网络有限公司']
# ['段璐', '女', 2007, 4, '设计', '插画', '特聘插画', '超艺信息有限公司']
# ['葛淑英', '女', 2008, 4, '运营', '传统运营', '中级传统运营', '凌颖信息科技有限公司']
# ['朱华', '男', 2004, 10, '运维', '服务器管理', '特聘服务器管理', '新宇龙信息信息有限公司']
# ['段浩', '男', 2011, 3, '运维', '数据库运维', '特聘数据库运维', '超艺信息有限公司']
# ['张畅', '女', 2001, 5, '设计', '插画', '高级插画', '海创网络有限公司']
# ['毛芳', '男', 2019, 10, '财务', '会计', '特聘会计', '国讯传媒有限公司']
# ['王凤英', '女', 2013, 11, '运营', '传统运营', '高级传统运营', '泰麒麟科技有限公司']
# ['谢帆', '女', 2004, 10, '运营', '新媒体运营', '中级新媒体运营', '彩虹网络有限公司']
# ['吴志强', '女', 2005, 6, '运维', '服务器管理', '中级服务器管理', '菊风公司传媒有限公司']
# ['黎波', '女', 2013, 1, '财务', '出纳', '初级出纳', '图龙信息科技有限公司']
# ['侯玉华', '女', 2009, 2, '运维', '数据库运维', '高级数据库运维', '浙大万朋网络有限公司']
# ['王淑英', '女', 2008, 8, '管理', '技术领导', '高级技术领导', '凌云信息有限公司']
# ['陈丽娟', '女', 2002, 10, '运维', '数据库运维', '特聘数据库运维', '中建创业网络有限公司']
# ['郭倩', '女', 2013, 10, '测试', '黑盒测试', '中级黑盒测试', '九方传媒有限公司']
# ['叶军', '女', 2010, 3, '财务', '出纳', '中级出纳', '信诚致远网络有限公司']
# ['刘坤', '女', 2011, 12, '开发', '后端开发', '特聘后端开发', '毕博诚科技有限公司']
# ['武军', '女', 2005, 1, '运营', '传统运营', '特聘传统运营', '鑫博腾飞网络有限公司']
# ['鞠欣', '男', 2014, 7, '设计', '插画', '中级插画', '创汇科技有限公司']
# ['牛凯', '女', 2004, 3, '测试', '白盒测试', '特聘白盒测试', '迪摩信息有限公司']
# ['唐兰英', '女', 2009, 6, '管理', '技术领导', '高级技术领导', '凌颖信息信息有限公司']
# ['王旭', '女', 2014, 3, '管理', '公司领导', '高级公司领导', '凌云网络有限公司']
# ['殷秀兰', '女', 2014, 3, '测试', '白盒测试', '高级白盒测试', '联通时科传媒有限公司']
# ['邓淑兰', '男', 2016, 2, '设计', '插画', '初级插画', '鑫博腾飞网络有限公司']
# ['蒋金凤', '男', 2017, 12, '运营', '传统运营', '高级传统运营', '联通时科网络有限公司']
# ['赵桂荣', '女', 2003, 12, '管理', '技术领导', '中级技术领导', '海创传媒有限公司']
# ['高璐', '女', 2001, 4, '财务', '会计', '高级会计', '凌颖信息网络有限公司']
# ['谢建华', '男', 2005, 10, '管理', '公司领导', '中级公司领导', '济南亿次元网络有限公司']
# ['余静', '男', 2018, 3, '运维', '数据库运维', '初级数据库运维', '东方峻景网络有限公司']
# ['马荣', '男', 2015, 4, '运维', '服务器管理', '中级服务器管理', '数字100信息有限公司']
# ['袁娟', '女', 2013, 2, '运维', '服务器管理', '初级服务器管理', '双敏电子网络有限公司']
# ['王慧', '男', 2010, 2, '运维', '数据库运维', '高级数据库运维', '时刻信息有限公司']
# ['王红霞', '女', 2007, 9, '设计', '插画', '高级插画', '济南亿次元信息有限公司']
# ['程琳', '男', 2006, 4, '财务', '会计', '特聘会计', '彩虹科技有限公司']
# ['朱桂香', '男', 2002, 1, '财务', '会计', '初级会计', '时刻传媒有限公司']
# ['李红', '男', 2016, 11, '设计', '插画', '初级插画', '华成育卓信息有限公司']
# ['徐利', '女', 2013, 6, '开发', '平台开发', '高级平台开发', '银嘉传媒有限公司']
# ['马杨', '男', 2013, 5, '财务', '出纳', '高级出纳', '东方峻景网络有限公司']
# ['古杨', '男', 2015, 3, '测试', '黑盒测试', '特聘黑盒测试', '雨林木风计算机信息有限公司']
# ['胡宇', '男', 2014, 1, '运营', '新媒体运营', '中级新媒体运营', '黄石金承信息有限公司']
# ['朱伟', '女', 2017, 4, '运维', '服务器管理', '特聘服务器管理', '浙大万朋网络有限公司']
# ['万军', '女', 2015, 11, '开发', '平台开发', '初级平台开发', '飞利信网络有限公司']
# ['宋晨', '男', 2007, 2, '运维', '数据库运维', '高级数据库运维', '信诚致远网络有限公司']
# ['杨东', '女', 2013, 3, '运营', '新媒体运营', '中级新媒体运营', '联软科技有限公司']
# ['钟芳', '女', 2009, 7, '财务', '出纳', '初级出纳', '泰麒麟科技有限公司']
# ['董晨', '男', 2009, 9, '管理', '技术领导', '初级技术领导', '开发区世创科技有限公司']
# ['黄雪梅', '男', 2017, 11, '运维', '数据库运维', '中级数据库运维', '七喜网络有限公司']
# ['成建华', '女', 2006, 7, '开发', '后端开发', '特聘后端开发', '明腾网络有限公司']
# ['刘丽华', '男', 2005, 6, '测试', '白盒测试', '特聘白盒测试', '凌云网络有限公司']
# ['张坤', '女', 2006, 2, '设计', '插画', '特聘插画', '银嘉传媒有限公司']
# ['徐鑫', '女', 2010, 6, '测试', '白盒测试', '特聘白盒测试', '超艺科技有限公司']
# ['田婷婷', '男', 2007, 6, '运维', '数据库运维', '特聘数据库运维', '方正科技科技有限公司']
# ['刘欣', '男', 2015, 11, '开发', '前端开发', '中级前端开发', '华泰通安传媒有限公司']
# ['韩建平', '女', 2017, 4, '测试', '白盒测试', '中级白盒测试', '联通时科科技有限公司']
# ['周林', '男', 2014, 12, '管理', '公司领导', '中级公司领导', '时空盒数字科技有限公司']
# ['赵霞', '女', 2009, 1, '运营', '新媒体运营', '特聘新媒体运营', '恒聪百汇科技有限公司']
# ['韩建华', '女', 2019, 10, '运维', '数据库运维', '中级数据库运维', '时空盒数字网络有限公司']
# ['庞鹏', '女', 2019, 3, '财务', '会计', '初级会计', '四通信息有限公司']
# ['姚雪梅', '男', 2005, 8, '测试', '白盒测试', '初级白盒测试', '思优科技有限公司']
# ['王桂花', '男', 2018, 6, '运营', '传统运营', '特聘传统运营', '兰金电子科技有限公司']
# ['许娟', '男', 2010, 5, '管理', '技术领导', '中级技术领导', '泰麒麟信息有限公司']
# ['江想', '女', 2016, 2, '运营', '传统运营', '中级传统运营', '时空盒数字信息有限公司']
# ['张秀芳', '女', 2012, 8, '财务', '出纳', '高级出纳', '群英网络有限公司']
# ['古莹', '男', 2015, 2, '财务', '会计', '初级会计', '四通信息有限公司']
# ['曹玉', '男', 2003, 4, '开发', '后端开发', '高级后端开发', '七喜信息有限公司']
# ['陈桂芝', '女', 2002, 11, '测试', '黑盒测试', '初级黑盒测试', '合联电子传媒有限公司']
# ['王梅', '女', 2013, 9, '开发', '前端开发', '初级前端开发', '雨林木风计算机科技有限公司']
# ['陈淑华', '男', 2016, 2, '财务', '会计', '高级会计', '维涛信息有限公司']
# ['张芳', '女', 2019, 3, '管理', '公司领导', '中级公司领导', '菊风公司科技有限公司']
# ['陆英', '男', 2006, 6, '设计', '插画', '特聘插画', '通际名联信息有限公司']
# ['彭玲', '男', 2003, 10, '财务', '出纳', '特聘出纳', '佳禾网络有限公司']
# ['李玲', '男', 2012, 1, '开发', '平台开发', '高级平台开发', '黄石金承信息有限公司']
# ['宋琳', '男', 2006, 9, '财务', '会计', '高级会计', '天开科技有限公司']
# ['杨建', '女', 2012, 5, '运维', '数据库运维', '高级数据库运维', '昊嘉信息有限公司']
# ['王桂英', '女', 2015, 2, '测试', '白盒测试', '中级白盒测试', '联软网络有限公司']
# ['张旭', '男', 2019, 9, '运维', '服务器管理', '中级服务器管理', '菊风公司网络有限公司']
# ['翟莹', '女', 2008, 7, '运营', '新媒体运营', '特聘新媒体运营', '创汇信息有限公司']
# ['王红霞', '男', 2006, 2, '运营', '新媒体运营', '高级新媒体运营', '天开科技有限公司']
# ['王晶', '女', 2002, 6, '财务', '出纳', '高级出纳', '双敏电子传媒有限公司']
# ['徐桂英', '男', 2006, 1, '管理', '技术领导', '特聘技术领导', '鑫博腾飞信息有限公司']
# ['曾健', '女', 2017, 9, '测试', '白盒测试', '初级白盒测试', '开发区世创信息有限公司']
# ['李玲', '女', 2008, 9, '运营', '传统运营', '特聘传统运营', '艾提科信传媒有限公司']
# ['唐凤英', '男', 2003, 5, '管理', '技术领导', '特聘技术领导', '凌云科技有限公司']
# ['丁淑华', '男', 2019, 1, '测试', '黑盒测试', '高级黑盒测试', '诺依曼软件科技有限公司']
# ['孟雪', '女', 2015, 2, '运营', '新媒体运营', '高级新媒体运营', '维涛信息有限公司']
# ['邵娟', '女', 2018, 3, '财务', '出纳', '初级出纳', '维旺明传媒有限公司']
# ['王丽丽', '男', 2005, 9, '测试', '黑盒测试', '初级黑盒测试', '戴硕电子网络有限公司']
# ['孙芳', '女', 2005, 3, '开发', '前端开发', '高级前端开发', '双敏电子传媒有限公司']
# ['鞠伟', '男', 2014, 2, '测试', '黑盒测试', '特聘黑盒测试', '数字100科技有限公司']
# ['孙秀云', '女', 2001, 10, '测试', '白盒测试', '初级白盒测试', '方正科技网络有限公司']
# ['周建华', '女', 2016, 8, '运维', '数据库运维', '高级数据库运维', '飞海科技科技有限公司']
# ['李秀珍', '女', 2003, 1, '运营', '传统运营', '初级传统运营', '太极信息有限公司']
# ['萧瑞', '男', 2007, 8, '管理', '公司领导', '中级公司领导', '兰金电子传媒有限公司']
# ['王涛', '女', 2003, 12, '运维', '数据库运维', '特聘数据库运维', '精芯传媒有限公司']
# ['蒋秀梅', '男', 2019, 7, '设计', '插画', '初级插画', '维旺明信息有限公司']
# ['林峰', '男', 2001, 9, '运维', '数据库运维', '高级数据库运维', '商软冠联信息有限公司']
# ['谢明', '女', 2010, 11, '设计', '原画', '中级原画', '兰金电子网络有限公司']
# ['傅淑英', '女', 2008, 12, '运营', '传统运营', '特聘传统运营', '佳禾网络有限公司']
# ['黄红梅', '男', 2005, 2, '管理', '技术领导', '高级技术领导', '联软网络有限公司']
# ['刘淑珍', '男', 2017, 5, '开发', '前端开发', '特聘前端开发', '泰麒麟传媒有限公司']
# ['朱颖', '女', 2014, 5, '管理', '技术领导', '高级技术领导', '四通网络有限公司']
# ['王志强', '男', 2015, 7, '运维', '服务器管理', '中级服务器管理', '飞海科技网络有限公司']
# ['吕春梅', '女', 2016, 5, '管理', '技术领导', '高级技术领导', '银嘉信息有限公司']
# ['徐琴', '男', 2006, 7, '财务', '会计', '中级会计', '黄石金承传媒有限公司']
# ['唐瑞', '女', 2004, 10, '设计', '原画', '高级原画', '凌云传媒有限公司']
# ['张凯', '男', 2017, 4, '运营', '传统运营', '中级传统运营', '维涛传媒有限公司']
# ['曲秀兰', '男', 2001, 12, '运维', '数据库运维', '中级数据库运维', '鸿睿思博传媒有限公司']
# ['夏军', '男', 2019, 12, '管理', '公司领导', '特聘公司领导', '天益传媒有限公司']
# ['刘军', '男', 2010, 8, '运营', '传统运营', '中级传统运营', '九方传媒有限公司']
# ['王旭', '男', 2001, 6, '设计', '原画', '初级原画', '易动力科技有限公司']
# ['魏博', '男', 2001, 3, '开发', '平台开发', '特聘平台开发', '银嘉科技有限公司']
# ['张红', '女', 2009, 6, '设计', '插画', '高级插画', '思优网络有限公司']
# ['李鑫', '男', 2010, 5, '测试', '黑盒测试', '高级黑盒测试', '凌颖信息科技有限公司']
# ['王丹', '男', 2016, 11, '设计', '插画', '特聘插画', '太极传媒有限公司']
# ['王文', '女', 2006, 6, '开发', '前端开发', '高级前端开发', '立信电子网络有限公司']
# ['罗秀兰', '女', 2012, 2, '测试', '黑盒测试', '初级黑盒测试', '恒聪百汇科技有限公司']
# ['张婷婷', '女', 2004, 4, '运维', '服务器管理', '中级服务器管理', '泰麒麟传媒有限公司']
# ['鞠红霞', '女', 2015, 3, '财务', '出纳', '初级出纳', '新宇龙信息网络有限公司']
# ['李桂荣', '女', 2001, 2, '开发', '后端开发', '初级后端开发', '易动力网络有限公司']
# ['张飞', '男', 2007, 1, '财务', '会计', '高级会计', '商软冠联传媒有限公司']
# ['文燕', '男', 2008, 8, '管理', '技术领导', '中级技术领导', '天益科技有限公司']
# ['刘小红', '女', 2008, 11, '测试', '黑盒测试', '高级黑盒测试', '超艺科技有限公司']
# ['翁岩', '女', 2015, 12, '运营', '传统运营', '初级传统运营', '良诺信息有限公司']
# ['彭桂英', '女', 2009, 4, '测试', '白盒测试', '初级白盒测试', '中建创业传媒有限公司']
# ['张霞', '女', 2004, 2, '运营', '新媒体运营', '中级新媒体运营', '菊风公司信息有限公司']
# ['龙彬', '男', 2007, 6, '管理', '公司领导', '中级公司领导', '思优信息有限公司']
# ['徐刚', '男', 2008, 7, '设计', '原画', '初级原画', '信诚致远信息有限公司']
# ['谷峰', '男', 2009, 7, '测试', '白盒测试', '特聘白盒测试', '创联世纪传媒有限公司']
# ['雷健', '女', 2015, 6, '管理', '技术领导', '初级技术领导', '华成育卓科技有限公司']
# ['刘雷', '女', 2017, 1, '运营', '传统运营', '高级传统运营', '黄石金承科技有限公司']
# ['赵淑珍', '男', 2009, 11, '设计', '插画', '中级插画', '精芯网络有限公司']
# ['卢凤英', '女', 2016, 12, '设计', '插画', '特聘插画', '昂歌信息传媒有限公司']
# ['王志强', '女', 2011, 8, '财务', '会计', '高级会计', '新宇龙信息信息有限公司']
# ['吕璐', '女', 2014, 10, '运营', '传统运营', '初级传统运营', '富罳传媒有限公司']
# ['马琴', '女', 2015, 5, '测试', '黑盒测试', '中级黑盒测试', '浦华众城网络有限公司']
# ['吕利', '女', 2001, 3, '测试', '黑盒测试', '中级黑盒测试', '时空盒数字网络有限公司']
# ['林桂兰', '男', 2003, 6, '财务', '出纳', '中级出纳', '中建创业信息有限公司']
# ['张勇', '女', 2019, 11, '运营', '传统运营', '特聘传统运营', '恩悌传媒有限公司']
# ['李雪', '男', 2019, 3, '运维', '服务器管理', '初级服务器管理', '南康传媒有限公司']
# ['李磊', '男', 2001, 5, '管理', '公司领导', '中级公司领导', '网新恒天科技有限公司']
# ['唐玉珍', '男', 2007, 6, '测试', '白盒测试', '高级白盒测试', '飞利信网络有限公司']
# ['黄秀珍', '女', 2016, 6, '运营', '传统运营', '初级传统运营', '黄石金承网络有限公司']
# ['刘洋', '男', 2014, 7, '设计', '插画', '中级插画', '开发区世创网络有限公司']
# ['赖凤兰', '女', 2011, 2, '设计', '原画', '初级原画', '开发区世创科技有限公司']
# ['金燕', '女', 2009, 1, '财务', '会计', '初级会计', '数字100传媒有限公司']
# ['彭敏', '女', 2011, 9, '开发', '平台开发', '初级平台开发', '银嘉传媒有限公司']
# ['王芳', '女', 2003, 10, '管理', '技术领导', '初级技术领导', '恩悌网络有限公司']
# ['庄阳', '男', 2003, 8, '设计', '原画', '高级原画', '昂歌信息科技有限公司']
# ['张帆', '女', 2012, 5, '运营', '新媒体运营', '初级新媒体运营', '明腾信息有限公司']
# ['孙岩', '女', 2016, 1, '测试', '黑盒测试', '特聘黑盒测试', '中建创业科技有限公司']
# ['李刚', '男', 2005, 5, '管理', '公司领导', '中级公司领导', '良诺信息有限公司']
# ['卓玉梅', '男', 2006, 2, '设计', '插画', '中级插画', '盟新传媒有限公司']
# ['温丹', '女', 2001, 3, '运营', '新媒体运营', '高级新媒体运营', '凌颖信息网络有限公司']
# ['陆欣', '女', 2019, 5, '财务', '出纳', '中级出纳', '明腾网络有限公司']
# ['马秀华', '男', 2018, 4, '运营', '传统运营', '中级传统运营', '立信电子传媒有限公司']
# ['张帆', '女', 2004, 11, '设计', '原画', '初级原画', '飞利信信息有限公司']
# ['石欣', '女', 2004, 4, '运营', '传统运营', '特聘传统运营', '四通网络有限公司']
# ['程小红', '男', 2013, 7, '设计', '原画', '特聘原画', '天益网络有限公司']
# ['朱丹', '女', 2015, 10, '管理', '公司领导', '中级公司领导', '华泰通安信息有限公司']
# ['王浩', '女', 2009, 3, '测试', '黑盒测试', '中级黑盒测试', '浦华众城科技有限公司']
# ['张玉', '女', 2018, 10, '运维', '服务器管理', '初级服务器管理', '鑫博腾飞信息有限公司']
# ['林淑珍', '女', 2002, 4, '运营', '传统运营', '中级传统运营', '开发区世创网络有限公司']
# ['谢燕', '女', 2006, 9, '管理', '公司领导', '特聘公司领导', '太极网络有限公司']
# ['王欢', '女', 2010, 12, '测试', '白盒测试', '特聘白盒测试', '超艺科技有限公司']
# ['李晶', '女', 2009, 5, '开发', '前端开发', '特聘前端开发', '创汇网络有限公司']
# ['袁雪', '男', 2015, 9, '运维', '服务器管理', '中级服务器管理', '银嘉科技有限公司']
# ['王丽丽', '女', 2018, 9, '运营', '传统运营', '中级传统运营', '联通时科传媒有限公司']
# ['应丽娟', '女', 2003, 4, '测试', '白盒测试', '高级白盒测试', '联软科技有限公司']
# ['彭洋', '男', 2008, 9, '运维', '数据库运维', '高级数据库运维', '七喜网络有限公司']
# ['赵英', '男', 2001, 2, '运维', '服务器管理', '中级服务器管理', '方正科技传媒有限公司']
# ['杨荣', '男', 2018, 7, '测试', '黑盒测试', '高级黑盒测试', '通际名联信息有限公司']
# ['李海燕', '女', 2006, 5, '设计', '插画', '特聘插画', '华远软件传媒有限公司']
# ['孙勇', '女', 2019, 5, '运维', '服务器管理', '中级服务器管理', '维旺明传媒有限公司']
# ['蒋阳', '女', 2013, 7, '运维', '数据库运维', '中级数据库运维', '天益信息有限公司']
# ['沙秀芳', '男', 2015, 11, '设计', '原画', '特聘原画', '凌颖信息传媒有限公司']
# ['田敏', '女', 2005, 8, '测试', '白盒测试', '初级白盒测试', '明腾信息有限公司']
# ['王畅', '女', 2002, 3, '运营', '传统运营', '高级传统运营', '图龙信息信息有限公司']
# ['杨雪梅', '女', 2005, 4, '运维', '服务器管理', '初级服务器管理', '浦华众城科技有限公司']
# ['侯坤', '男', 2010, 2, '运维', '数据库运维', '中级数据库运维', '时空盒数字科技有限公司']
# ['柯坤', '女', 2007, 8, '运维', '数据库运维', '中级数据库运维', '华成育卓科技有限公司']
# ['凌玉梅', '女', 2007, 7, '管理', '公司领导', '特聘公司领导', '昂歌信息网络有限公司']
# ['张娟', '女', 2019, 10, '开发', '后端开发', '高级后端开发', '昂歌信息信息有限公司']
# ['孙彬', '女', 2002, 7, '开发', '前端开发', '特聘前端开发', '凌云网络有限公司']
# ['张晨', '男', 2005, 1, '测试', '白盒测试', '高级白盒测试', '太极网络有限公司']
# ['黄瑜', '男', 2003, 12, '测试', '白盒测试', '高级白盒测试', '东方峻景网络有限公司']
# ['郭雷', '女', 2008, 6, '财务', '会计', '特聘会计', '凌云传媒有限公司']
# ['周莉', '男', 2008, 2, '开发', '前端开发', '特聘前端开发', '万迅电脑传媒有限公司']
# ['巫柳', '男', 2018, 5, '运维', '数据库运维', '初级数据库运维', '华远软件科技有限公司']
# ['黄健', '女', 2011, 5, '开发', '前端开发', '特聘前端开发', '万迅电脑网络有限公司']
# ['廖莹', '男', 2016, 3, '设计', '插画', '中级插画', '联通时科网络有限公司']
# ['陆玉梅', '男', 2007, 11, '开发', '平台开发', '初级平台开发', '开发区世创科技有限公司']
# ['张丽娟', '女', 2019, 9, '测试', '黑盒测试', '特聘黑盒测试', '华成育卓网络有限公司']
# ['胡阳', '女', 2005, 12, '财务', '会计', '高级会计', '九方科技有限公司']
# ['杨梅', '女', 2005, 3, '运营', '新媒体运营', '高级新媒体运营', '趋势传媒有限公司']
# ['王颖', '女', 2006, 2, '财务', '会计', '高级会计', '网新恒天传媒有限公司']
# ['宋桂芳', '男', 2018, 5, '管理', '公司领导', '特聘公司领导', '合联电子科技有限公司']
# ['任文', '女', 2012, 10, '运维', '服务器管理', '高级服务器管理', '太极科技有限公司']
# ['魏建', '女', 2018, 10, '开发', '平台开发', '特聘平台开发', '晖来计算机科技有限公司']
# ['李艳', '男', 2016, 1, '运营', '新媒体运营', '特聘新媒体运营', '方正科技科技有限公司']
# ['刘玉兰', '男', 2018, 1, '运营', '新媒体运营', '初级新媒体运营', '四通网络有限公司']
# ['钟桂芝', '男', 2006, 7, '设计', '插画', '初级插画', '群英信息有限公司']
# ['王华', '男', 2017, 12, '管理', '技术领导', '中级技术领导', '万迅电脑传媒有限公司']
# ['夏淑华', '女', 2005, 11, '运营', '新媒体运营', '初级新媒体运营', '鸿睿思博传媒有限公司']
# ['钱帆', '男', 2011, 5, '管理', '技术领导', '初级技术领导', '九方科技有限公司']
# ['徐小红', '男', 2015, 1, '财务', '出纳', '中级出纳', '富罳科技有限公司']
# ['陈瑜', '男', 2016, 3, '测试', '白盒测试', '初级白盒测试', '时空盒数字网络有限公司']
# ['刘燕', '男', 2011, 10, '运维', '服务器管理', '中级服务器管理', '飞利信网络有限公司']
# ['张金凤', '女', 2010, 7, '运营', '新媒体运营', '中级新媒体运营', '天开科技有限公司']
# ['方刚', '男', 2017, 10, '测试', '白盒测试', '高级白盒测试', '快讯信息有限公司']
# ['林欢', '男', 2001, 8, '运营', '传统运营', '中级传统运营', '黄石金承传媒有限公司']
# ['朱志强', '男', 2010, 10, '设计', '插画', '中级插画', '易动力信息有限公司']
# ['潘敏', '女', 2017, 4, '管理', '公司领导', '初级公司领导', '凌颖信息网络有限公司']
# ['李成', '女', 2008, 6, '运维', '服务器管理', '高级服务器管理', '飞利信传媒有限公司']
# ['张旭', '女', 2003, 9, '开发', '后端开发', '特聘后端开发', '明腾网络有限公司']
# ['管涛', '男', 2013, 12, '开发', '后端开发', '初级后端开发', '菊风公司科技有限公司']
# ['高萍', '男', 2003, 6, '财务', '会计', '高级会计', '数字100科技有限公司']
# ['刘斌', '女', 2017, 2, '运营', '新媒体运营', '初级新媒体运营', '海创网络有限公司']
# ['徐欢', '女', 2019, 10, '运维', '服务器管理', '特聘服务器管理', '毕博诚信息有限公司']
# ['段秀珍', '男', 2004, 6, '运营', '传统运营', '高级传统运营', '商软冠联科技有限公司']
# ['梁斌', '女', 2011, 10, '运维', '服务器管理', '初级服务器管理', '南康传媒有限公司']
# ['刘畅', '男', 2015, 2, '管理', '公司领导', '特聘公司领导', '飞海科技网络有限公司']
# ['李秀珍', '女', 2005, 4, '设计', '原画', '中级原画', '图龙信息信息有限公司']
# ['戴旭', '女', 2019, 4, '开发', '平台开发', '初级平台开发', '易动力网络有限公司']
# ['谢敏', '女', 2004, 6, '设计', '插画', '中级插画', '快讯网络有限公司']
# ['陈英', '女', 2007, 8, '开发', '前端开发', '特聘前端开发', '华远软件科技有限公司']
# ['徐健', '男', 2005, 9, '管理', '技术领导', '初级技术领导', '双敏电子信息有限公司']
# ['王丽华', '男', 2014, 9, '开发', '前端开发', '初级前端开发', '联通时科网络有限公司']
# ['欧玉英', '女', 2009, 8, '测试', '黑盒测试', '初级黑盒测试', '精芯科技有限公司']
# ['李玉', '女', 2017, 3, '管理', '技术领导', '高级技术领导', '方正科技网络有限公司']
# ['袁萍', '男', 2003, 1, '运维', '服务器管理', '初级服务器管理', '南康信息有限公司']
# ['班玉珍', '男', 2016, 1, '设计', '插画', '初级插画', '海创传媒有限公司']
# ['邵颖', '男', 2005, 8, '管理', '公司领导', '初级公司领导', '创汇科技有限公司']
# ['刘秀华', '男', 2007, 8, '财务', '会计', '高级会计', '信诚致远信息有限公司']
# ['胡东', '女', 2007, 5, '管理', '公司领导', '中级公司领导', '凌颖信息传媒有限公司']
# ['罗琳', '女', 2017, 4, '开发', '前端开发', '初级前端开发', '艾提科信网络有限公司']
# ['费秀云', '男', 2007, 7, '测试', '黑盒测试', '中级黑盒测试', '中建创业传媒有限公司']
# ['张宇', '男', 2003, 7, '管理', '技术领导', '中级技术领导', '泰麒麟网络有限公司']
# ['马晶', '女', 2013, 1, '开发', '前端开发', '特聘前端开发', '维旺明网络有限公司']
# ['赵佳', '男', 2015, 5, '开发', '后端开发', '中级后端开发', '飞海科技科技有限公司']
# ['侯柳', '男', 2001, 6, '开发', '后端开发', '初级后端开发', '超艺科技有限公司']
# ['薛秀荣', '男', 2013, 9, '管理', '公司领导', '初级公司领导', '浙大万朋科技有限公司']
# ['赵波', '女', 2001, 1, '设计', '原画', '中级原画', '中建创业信息有限公司']
# ['李春梅', '女', 2008, 10, '管理', '公司领导', '特聘公司领导', '盟新科技有限公司']
# ['苏小红', '男', 2016, 5, '运营', '传统运营', '高级传统运营', 'MBP软件传媒有限公司']
# ['陈娜', '女', 2009, 1, '设计', '插画', '初级插画', '迪摩网络有限公司']
# ['马桂香', '女', 2012, 4, '测试', '白盒测试', '中级白盒测试', '泰麒麟科技有限公司']
# ['吕颖', '男', 2008, 10, '运营', '新媒体运营', '初级新媒体运营', '和泰网络有限公司']
# ['刘玉英', '男', 2004, 5, '财务', '会计', '高级会计', '开发区世创传媒有限公司']
# ['黄慧', '女', 2011, 7, '运营', '传统运营', '初级传统运营', '飞利信传媒有限公司']
# ['李丽娟', '女', 2012, 4, '设计', '插画', '初级插画', '国讯科技有限公司']
# ['陈涛', '男', 2006, 5, '开发', '后端开发', '特聘后端开发', '飞海科技传媒有限公司']
# ['叶玉兰', '女', 2003, 4, '设计', '插画', '特聘插画', '国讯科技有限公司']
# ['程佳', '女', 2006, 5, '财务', '出纳', '特聘出纳', '昂歌信息科技有限公司']
# ['曾帅', '女', 2003, 11, '测试', '黑盒测试', '中级黑盒测试', '恩悌科技有限公司']
# ['谭丹', '男', 2017, 12, '开发', '前端开发', '特聘前端开发', '海创传媒有限公司']
# ['张伟', '女', 2009, 8, '财务', '会计', '特聘会计', '南康信息有限公司']
# ['吕兵', '男', 2004, 3, '财务', '出纳', '初级出纳', '趋势科技有限公司']
# ['王秀珍', '男', 2016, 11, '运营', '传统运营', '特聘传统运营', '创汇信息有限公司']
# ['刘秀云', '女', 2016, 12, '设计', '原画', '初级原画', '和泰网络有限公司']
# ['汪秀梅', '男', 2007, 10, '财务', '出纳', '初级出纳', '新宇龙信息信息有限公司']
# ['顾艳', '男', 2017, 7, '管理', '技术领导', '特聘技术领导', '双敏电子信息有限公司']
# ['张红梅', '男', 2019, 8, '运营', '新媒体运营', '特聘新媒体运营', '昊嘉网络有限公司']
# ['苏冬梅', '男', 2018, 3, '财务', '出纳', '特聘出纳', '联软传媒有限公司']
# ['余强', '男', 2011, 8, '管理', '公司领导', '初级公司领导', '海创传媒有限公司']
# ['钱淑华', '女', 2007, 7, '运营', '新媒体运营', '高级新媒体运营', '艾提科信科技有限公司']
# ['童静', '男', 2002, 9, '设计', '原画', '特聘原画', '精芯网络有限公司']
# ['刘桂芝', '男', 2015, 9, '开发', '前端开发', '初级前端开发', '凌颖信息网络有限公司']
# ['张秀兰', '男', 2013, 11, '设计', '原画', '中级原画', '七喜科技有限公司']
# ['胡帅', '女', 2019, 5, '测试', '白盒测试', '初级白盒测试', '戴硕电子网络有限公司']
# ['马彬', '女', 2012, 10, '开发', '后端开发', '初级后端开发', '飞海科技网络有限公司']
# ['郭波', '男', 2015, 7, '设计', '原画', '中级原画', '浦华众城信息有限公司']
# ['杨丽华', '男', 2010, 12, '测试', '黑盒测试', '高级黑盒测试', '华泰通安信息有限公司']
# ['刘淑华', '女', 2005, 9, '运维', '数据库运维', '中级数据库运维', '易动力网络有限公司']
# ['任梅', '男', 2018, 9, '测试', '黑盒测试', '特聘黑盒测试', '创亿传媒有限公司']
# ['王帅', '女', 2012, 6, '测试', '黑盒测试', '中级黑盒测试', '维涛信息有限公司']
# ['陶淑华', '女', 2007, 3, '设计', '原画', '特聘原画', '信诚致远传媒有限公司']
# ['李凤兰', '女', 2016, 3, '开发', '后端开发', '初级后端开发', '创联世纪信息有限公司']
# ['田莹', '男', 2007, 12, '测试', '黑盒测试', '高级黑盒测试', '巨奥网络有限公司']
# ['石涛', '男', 2014, 2, '管理', '公司领导', '中级公司领导', '中建创业网络有限公司']
# ['申兰英', '男', 2013, 8, '运营', '新媒体运营', '中级新媒体运营', '良诺网络有限公司']
# ['刘颖', '男', 2007, 12, '运营', '新媒体运营', '初级新媒体运营', '时空盒数字科技有限公司']
# ['孙杰', '女', 2007, 6, '设计', '原画', '中级原画', '七喜信息有限公司']
# ['赵明', '男', 2007, 11, '运营', '新媒体运营', '高级新媒体运营', '彩虹网络有限公司']
# ['沈俊', '女', 2014, 7, '运营', '新媒体运营', '特聘新媒体运营', '飞海科技网络有限公司']
# ['康红', '男', 2014, 5, '财务', '出纳', '中级出纳', '和泰信息有限公司']
# ['董博', '男', 2006, 5, '财务', '出纳', '初级出纳', '万迅电脑信息有限公司']
# ['李燕', '男', 2013, 12, '管理', '技术领导', '高级技术领导', '飞利信传媒有限公司']
# ['蓝帅', '男', 2002, 7, '管理', '技术领导', '初级技术领导', '新格林耐特信息有限公司']
# ['王欢', '男', 2017, 5, '运营', '传统运营', '高级传统运营', '兰金电子信息有限公司']
# ['马涛', '男', 2007, 1, '运维', '数据库运维', '特聘数据库运维', '凌颖信息信息有限公司']
# ['顾娜', '女', 2014, 3, '测试', '白盒测试', '高级白盒测试', '和泰科技有限公司']
# ['常秀云', '女', 2017, 3, '运营', '新媒体运营', '特聘新媒体运营', 'MBP软件科技有限公司']
# ['王秀梅', '男', 2013, 11, '设计', '插画', '特聘插画', '华远软件信息有限公司']
# ['文淑英', '女', 2007, 9, '开发', '前端开发', '特聘前端开发', '昂歌信息信息有限公司']
# ['刘玲', '女', 2015, 1, '设计', '插画', '中级插画', '海创网络有限公司']
# ['陈静', '女', 2013, 6, '运营', '传统运营', '特聘传统运营', '易动力科技有限公司']
# ['罗志强', '女', 2017, 9, '测试', '白盒测试', '中级白盒测试', '新格林耐特传媒有限公司']
# ['丁玉兰', '女', 2007, 3, '运营', '新媒体运营', '高级新媒体运营', '维旺明网络有限公司']
# ['白淑珍', '男', 2005, 1, '管理', '公司领导', '高级公司领导', '时空盒数字网络有限公司']
# ['向秀荣', '女', 2005, 6, '测试', '白盒测试', '特聘白盒测试', '图龙信息科技有限公司']
# ['孙秀兰', '男', 2013, 2, '运营', '新媒体运营', '初级新媒体运营', '合联电子传媒有限公司']
# ['豆春梅', '男', 2015, 4, '开发', '后端开发', '中级后端开发', '迪摩网络有限公司']
# ['杜亮', '男', 2018, 4, '管理', '公司领导', '中级公司领导', '海创科技有限公司']
# ['林帅', '男', 2001, 5, '运营', '传统运营', '特聘传统运营', '南康信息有限公司']
# ['许坤', '男', 2007, 5, '运维', '服务器管理', '初级服务器管理', '浙大万朋传媒有限公司']
# ['穆颖', '男', 2016, 2, '运营', '新媒体运营', '初级新媒体运营', '创亿科技有限公司']
# ['马瑜', '男', 2018, 12, '管理', '技术领导', '中级技术领导', '盟新科技有限公司']
# ['祝婷', '女', 2017, 2, '测试', '白盒测试', '高级白盒测试', '恒聪百汇传媒有限公司']
# ['薛洁', '男', 2008, 2, '开发', '平台开发', '初级平台开发', '巨奥科技有限公司']
# ['王雷', '女', 2010, 3, '运营', '新媒体运营', '初级新媒体运营', '济南亿次元网络有限公司']
# ['李琳', '女', 2009, 6, '设计', '原画', '中级原画', '中建创业科技有限公司']
# ['高健', '女', 2003, 11, '管理', '技术领导', '特聘技术领导', '创联世纪信息有限公司']
# ['智娜', '男', 2001, 7, '管理', '技术领导', '中级技术领导', '新格林耐特信息有限公司']
# ['赵勇', '男', 2018, 4, '运维', '服务器管理', '中级服务器管理', '和泰传媒有限公司']
# ['张利', '女', 2010, 5, '财务', '出纳', '中级出纳', '凌云科技有限公司']
# ['许杨', '女', 2011, 11, '运营', '新媒体运营', '高级新媒体运营', '浦华众城传媒有限公司']
# ['冉斌', '女', 2007, 6, '管理', '技术领导', '特聘技术领导', '凌云传媒有限公司']
# ['方小红', '女', 2011, 10, '设计', '原画', '高级原画', '超艺信息有限公司']
# ['谭芳', '女', 2010, 4, '管理', '技术领导', '高级技术领导', '新格林耐特网络有限公司']
# ['朱淑华', '男', 2012, 8, '运营', '新媒体运营', '高级新媒体运营', '易动力科技有限公司']
# ['陈云', '男', 2001, 3, '测试', '黑盒测试', '初级黑盒测试', '群英信息有限公司']
# ['迟金凤', '男', 2007, 1, '运营', '传统运营', '中级传统运营', '易动力网络有限公司']
# ['向刚', '男', 2008, 8, '财务', '出纳', '特聘出纳', '联软信息有限公司']
# ['王建', '男', 2012, 9, '开发', '后端开发', '特聘后端开发', '昂歌信息传媒有限公司']
# ['林海燕', '男', 2013, 7, '开发', '后端开发', '初级后端开发', '东方峻景传媒有限公司']
# ['刘明', '女', 2016, 8, '运营', '传统运营', '中级传统运营', '济南亿次元信息有限公司']
# ['黄勇', '男', 2017, 5, '开发', '后端开发', '特聘后端开发', '维涛信息有限公司']
# ['吉芳', '女', 2013, 11, '管理', '公司领导', '高级公司领导', '黄石金承科技有限公司']
# ['殷玉', '男', 2012, 9, '设计', '原画', '中级原画', '凌颖信息网络有限公司']
# ['陈娟', '女', 2001, 8, '财务', '出纳', '中级出纳', '维旺明科技有限公司']
# ['姚楠', '女', 2003, 6, '运营', '新媒体运营', '特聘新媒体运营', '七喜传媒有限公司']
# ['强俊', '女', 2015, 8, '设计', '插画', '特聘插画', '七喜信息有限公司']
# ['何浩', '女', 2010, 8, '设计', '原画', '初级原画', '华远软件网络有限公司']
# ['张宇', '女', 2012, 5, '运营', '传统运营', '高级传统运营', '华成育卓网络有限公司']
# ['汪颖', '男', 2008, 7, '设计', '原画', '特聘原画', '双敏电子网络有限公司']
# ['万玉英', '女', 2001, 2, '开发', '平台开发', '高级平台开发', '快讯信息有限公司']
# ['纪帅', '男', 2018, 8, '测试', '白盒测试', '特聘白盒测试', '黄石金承信息有限公司']
# ['马明', '女', 2010, 8, '运营', '传统运营', '特聘传统运营', '四通信息有限公司']
# ['顾艳', '女', 2003, 11, '设计', '插画', '初级插画', '联软传媒有限公司']
# ['杨莹', '男', 2005, 2, '财务', '出纳', '初级出纳', '太极传媒有限公司']
# ['郑彬', '男', 2017, 2, '运维', '服务器管理', '中级服务器管理', '浙大万朋网络有限公司']
# ['李兵', '男', 2016, 6, '管理', '技术领导', '中级技术领导', '巨奥传媒有限公司']
# ['赵冬梅', '男', 2007, 9, '运营', '传统运营', '初级传统运营', '天益传媒有限公司']
# ['吕杨', '女', 2005, 7, '设计', '插画', '中级插画', '网新恒天科技有限公司']
# ['智秀英', '男', 2005, 7, '运营', '传统运营', '高级传统运营', '惠派国际公司传媒有限公司']
# ['杨琴', '女', 2004, 9, '开发', '平台开发', '高级平台开发', '双敏电子传媒有限公司']
# ['孙柳', '男', 2011, 1, '测试', '白盒测试', '高级白盒测试', '鑫博腾飞科技有限公司']
# ['张华', '女', 2008, 3, '测试', '白盒测试', '初级白盒测试', '商软冠联信息有限公司']
# ['张瑜', '男', 2011, 2, '测试', '白盒测试', '特聘白盒测试', '思优科技有限公司']
# ['徐鑫', '女', 2007, 2, '开发', '前端开发', '初级前端开发', '思优信息有限公司']
# ['徐健', '男', 2009, 6, '运营', '新媒体运营', '特聘新媒体运营', '同兴万点传媒有限公司']
# ['甘军', '男', 2009, 10, '财务', '出纳', '高级出纳', '明腾传媒有限公司']
# ['袁帅', '男', 2005, 1, '设计', '插画', '初级插画', '华泰通安信息有限公司']
# ['阎柳', '男', 2014, 2, '测试', '黑盒测试', '初级黑盒测试', '通际名联科技有限公司']
# ['张飞', '男', 2005, 3, '设计', '插画', '初级插画', '信诚致远信息有限公司']
# ['刘飞', '女', 2005, 10, '管理', '技术领导', '高级技术领导', '浙大万朋信息有限公司']
# ['张秀梅', '男', 2005, 8, '设计', '原画', '高级原画', '创汇传媒有限公司']
# ['米海燕', '男', 2015, 8, '管理', '公司领导', '特聘公司领导', '鑫博腾飞信息有限公司']
# ['刘帅', '女', 2017, 9, '管理', '技术领导', '中级技术领导', '维涛信息有限公司']
# ['张敏', '男', 2009, 8, '运维', '数据库运维', '中级数据库运维', '海创传媒有限公司']
# ['蔡帆', '女', 2011, 2, '开发', '后端开发', '高级后端开发', '万迅电脑传媒有限公司']
# ['杨磊', '女', 2018, 10, '设计', '插画', '高级插画', '巨奥科技有限公司']
# ['李宇', '女', 2012, 8, '财务', '会计', '中级会计', '合联电子科技有限公司']
# ['韩明', '男', 2007, 6, '管理', '技术领导', '中级技术领导', '兰金电子信息有限公司']
# ['黄波', '男', 2007, 12, '财务', '出纳', '初级出纳', '双敏电子网络有限公司']
# ['胡婷婷', '女', 2010, 2, '开发', '前端开发', '中级前端开发', '彩虹信息有限公司']
# ['韩雷', '女', 2019, 12, '财务', '出纳', '中级出纳', '凌颖信息传媒有限公司']
# ['高帆', '女', 2009, 9, '测试', '黑盒测试', '特聘黑盒测试', '诺依曼软件科技有限公司']
# ['林颖', '男', 2006, 4, '设计', '插画', '初级插画', '银嘉传媒有限公司']
# ['王英', '男', 2005, 12, '运维', '服务器管理', '初级服务器管理', '九方信息有限公司']
# ['吕彬', '男', 2004, 12, '财务', '出纳', '中级出纳', '南康科技有限公司']
# ['邓丽娟', '男', 2019, 5, '财务', '出纳', '初级出纳', '黄石金承科技有限公司']
# ['潘燕', '女', 2007, 6, '设计', '插画', '高级插画', '良诺科技有限公司']
# ['文红梅', '男', 2014, 10, '运维', '数据库运维', '中级数据库运维', '华远软件信息有限公司']
# ['赵林', '男', 2018, 1, '运营', '传统运营', '中级传统运营', '双敏电子网络有限公司']
# ['陈莉', '男', 2010, 4, '开发', '平台开发', '初级平台开发', '彩虹科技有限公司']
# ['杨桂珍', '女', 2010, 3, '开发', '平台开发', '高级平台开发', '万迅电脑传媒有限公司']
# ['李晨', '男', 2011, 3, '运营', '传统运营', '高级传统运营', '联通时科科技有限公司']
# ['曾婷婷', '男', 2019, 7, '运营', '新媒体运营', '中级新媒体运营', '通际名联传媒有限公司']
# ['谢凤英', '男', 2004, 7, '运维', '服务器管理', '初级服务器管理', '天开传媒有限公司']
# ['赵小红', '女', 2012, 12, '开发', '前端开发', '初级前端开发', '东方峻景网络有限公司']
# ['张柳', '女', 2008, 3, '开发', '平台开发', '特聘平台开发', '联通时科科技有限公司']
# ['危凤英', '女', 2008, 7, '运维', '服务器管理', '中级服务器管理', '鑫博腾飞科技有限公司']
# ['田明', '女', 2014, 10, '开发', '后端开发', '中级后端开发', '通际名联信息有限公司']
# ['王阳', '女', 2018, 11, '管理', '技术领导', '初级技术领导', '富罳网络有限公司']
# ['吴莹', '男', 2019, 5, '运营', '传统运营', '初级传统运营', '万迅电脑信息有限公司']
# ['周秀梅', '男', 2014, 12, '财务', '会计', '高级会计', '中建创业科技有限公司']
# ['谭丽华', '男', 2011, 9, '管理', '技术领导', '初级技术领导', '联软科技有限公司']
# ['王淑兰', '女', 2005, 9, '运营', '传统运营', '初级传统运营', '兰金电子信息有限公司']
# ['覃红', '男', 2005, 3, '设计', '插画', '中级插画', '中建创业传媒有限公司']
# ['李晨', '女', 2013, 2, '财务', '出纳', '高级出纳', '东方峻景科技有限公司']
# ['刘婷', '男', 2015, 3, '开发', '前端开发', '特聘前端开发', '艾提科信网络有限公司']
# ['李楠', '女', 2014, 7, '运维', '服务器管理', '初级服务器管理', 'MBP软件传媒有限公司']
# ['李小红', '男', 2014, 7, '财务', '出纳', '中级出纳', '凌云科技有限公司']
# ['何雪梅', '女', 2010, 8, '运营', '传统运营', '初级传统运营', '浦华众城网络有限公司']
# ['胡建平', '女', 2008, 2, '运营', '新媒体运营', '特聘新媒体运营', '方正科技传媒有限公司']
# ['刘彬', '男', 2003, 9, '测试', '白盒测试', '高级白盒测试', '彩虹信息有限公司']
# ['邹秀华', '女', 2013, 3, '开发', '后端开发', '中级后端开发', '四通传媒有限公司']
# ['符金凤', '男', 2009, 9, '开发', '前端开发', '高级前端开发', '思优网络有限公司']
# ['张玉英', '男', 2004, 5, '运维', '数据库运维', '特聘数据库运维', '菊风公司科技有限公司']
# ['张秀云', '女', 2016, 8, '运营', '新媒体运营', '高级新媒体运营', '佳禾信息有限公司']
# ['朱淑英', '女', 2005, 2, '开发', '平台开发', '初级平台开发', '华远软件科技有限公司']
# ['王琴', '男', 2011, 7, '财务', '出纳', '高级出纳', '凌颖信息网络有限公司']
# ['姜超', '女', 2016, 7, '运维', '服务器管理', '中级服务器管理', '昂歌信息传媒有限公司']
# ['廖健', '女', 2013, 11, '开发', '平台开发', '高级平台开发', '易动力网络有限公司']
# ['黄梅', '女', 2004, 6, '运营', '新媒体运营', '高级新媒体运营', '惠派国际公司科技有限公司']
# ['黄淑珍', '女', 2008, 6, '财务', '出纳', '特聘出纳', '富罳信息有限公司']
# ['韩勇', '女', 2011, 9, '测试', '白盒测试', '特聘白盒测试', '东方峻景科技有限公司']
# ['黄丹', '女', 2012, 8, '运营', '传统运营', '初级传统运营', '华泰通安信息有限公司']
# ['马岩', '男', 2019, 3, '财务', '会计', '中级会计', '雨林木风计算机传媒有限公司']
# ['尹荣', '女', 2009, 2, '财务', '会计', '特聘会计', '通际名联科技有限公司']
# ['沈坤', '女', 2015, 11, '运营', '传统运营', '中级传统运营', '商软冠联传媒有限公司']
# ['吴娟', '女', 2006, 7, '测试', '白盒测试', '特聘白盒测试', '昂歌信息网络有限公司']
# ['凌桂荣', '女', 2018, 5, '运维', '数据库运维', '高级数据库运维', '网新恒天信息有限公司']
# ['王娜', '男', 2011, 9, '测试', '黑盒测试', '高级黑盒测试', '七喜科技有限公司']
# ['吴丹', '女', 2011, 9, '运维', '数据库运维', '特聘数据库运维', '思优信息有限公司']
# ['宋华', '女', 2003, 10, '运营', '新媒体运营', '初级新媒体运营', '创汇科技有限公司']
# ['常婷', '女', 2003, 2, '运维', '服务器管理', '高级服务器管理', '菊风公司网络有限公司']
# ['吴凯', '女', 2001, 5, '设计', '插画', '中级插画', '昂歌信息网络有限公司']
# ['王军', '女', 2019, 5, '测试', '黑盒测试', '高级黑盒测试', '超艺信息有限公司']
# ['周桂兰', '男', 2001, 12, '运维', '服务器管理', '高级服务器管理', '时刻传媒有限公司']
# ['李丽', '男', 2018, 10, '运营', '新媒体运营', '初级新媒体运营', '戴硕电子科技有限公司']
# ['徐淑英', '女', 2019, 10, '运营', '传统运营', '中级传统运营', '精芯科技有限公司']
# ['刘娜', '男', 2008, 6, '财务', '会计', '中级会计', '新宇龙信息信息有限公司']
# ['巫淑英', '女', 2014, 2, '测试', '白盒测试', '初级白盒测试', '晖来计算机传媒有限公司']
# ['王帆', '女', 2002, 11, '管理', '公司领导', '初级公司领导', '华泰通安科技有限公司']
# ['王瑞', '女', 2010, 9, '开发', '平台开发', '初级平台开发', '新宇龙信息科技有限公司']
# ['董畅', '男', 2013, 12, '运营', '传统运营', '特聘传统运营', '华远软件传媒有限公司']
# ['田琴', '男', 2017, 11, '运营', '传统运营', '初级传统运营', '九方网络有限公司']
# ['石红霞', '女', 2014, 3, '财务', '会计', '高级会计', '精芯网络有限公司']
# ['陈彬', '女', 2003, 9, '运维', '数据库运维', '高级数据库运维', '联通时科科技有限公司']
# ['徐鹏', '男', 2006, 6, '设计', '原画', '初级原画', '商软冠联信息有限公司']
# ['李鹏', '女', 2011, 3, '管理', '公司领导', '初级公司领导', '维旺明信息有限公司']
# ['韩博', '女', 2016, 2, '开发', '后端开发', '初级后端开发', '戴硕电子传媒有限公司']
# ['侯秀华', '女', 2008, 2, '测试', '白盒测试', '高级白盒测试', '兰金电子网络有限公司']
# ['杨鹏', '女', 2008, 7, '财务', '出纳', '初级出纳', '立信电子传媒有限公司']
# ['张琳', '女', 2005, 12, '运维', '数据库运维', '高级数据库运维', '易动力网络有限公司']
# ['李玉梅', '女', 2009, 9, '运维', '服务器管理', '特聘服务器管理', '南康信息有限公司']
# ['江婷', '女', 2017, 3, '财务', '会计', '高级会计', '南康科技有限公司']
# ['魏鑫', '女', 2016, 9, '设计', '插画', '高级插画', '晖来计算机科技有限公司']
# ['贾琳', '男', 2015, 4, '测试', '白盒测试', '高级白盒测试', '群英传媒有限公司']
# ['雷倩', '女', 2003, 11, '设计', '原画', '特聘原画', '商软冠联网络有限公司']
# ['郭玉兰', '女', 2001, 5, '测试', '黑盒测试', '特聘黑盒测试', '四通信息有限公司']
# ['刘杨', '女', 2002, 9, '运维', '服务器管理', '中级服务器管理', '新格林耐特传媒有限公司']
# ['张龙', '男', 2016, 4, '设计', '插画', '中级插画', '精芯信息有限公司']
# ['梁云', '男', 2017, 9, '设计', '原画', '初级原画', '四通网络有限公司']
# ['李桂荣', '男', 2019, 10, '运维', '数据库运维', '中级数据库运维', '精芯网络有限公司']
# ['邵桂兰', '男', 2016, 12, '运营', '新媒体运营', '特聘新媒体运营', '四通信息有限公司']
# ['宋建华', '女', 2016, 12, '运营', '新媒体运营', '高级新媒体运营', '信诚致远传媒有限公司']
# ['任帅', '男', 2018, 9, '设计', '插画', '中级插画', '华成育卓信息有限公司']
# ['王丹丹', '男', 2004, 12, '管理', '技术领导', '中级技术领导', '易动力网络有限公司']
# ['王莹', '女', 2005, 9, '设计', '原画', '初级原画', '佳禾信息有限公司']
# ['崔琳', '男', 2005, 5, '开发', '前端开发', '高级前端开发', '凌云传媒有限公司']
# ['昝彬', '女', 2014, 7, '测试', '黑盒测试', '特聘黑盒测试', '联通时科传媒有限公司']
# ['张莹', '男', 2008, 1, '运营', '新媒体运营', '高级新媒体运营', '昂歌信息科技有限公司']
# ['周东', '男', 2006, 9, '开发', '后端开发', '特聘后端开发', '明腾信息有限公司']
# ['李杨', '女', 2010, 11, '设计', '插画', '初级插画', '恩悌传媒有限公司']
# ['赵桂香', '男', 2018, 6, '测试', '白盒测试', '初级白盒测试', '方正科技网络有限公司']
# ['鞠娜', '女', 2017, 10, '开发', '前端开发', '高级前端开发', '图龙信息科技有限公司']
# ['蔡秀梅', '男', 2008, 4, '财务', '出纳', '初级出纳', '泰麒麟网络有限公司']
# ['唐文', '男', 2019, 12, '财务', '会计', '初级会计', '东方峻景网络有限公司']
# ['曾雪梅', '男', 2018, 12, '管理', '公司领导', '初级公司领导', '维涛网络有限公司']
# ['袁春梅', '女', 2011, 4, '运维', '数据库运维', '高级数据库运维', '方正科技科技有限公司']
# ['胡伟', '男', 2016, 6, '运营', '新媒体运营', '特聘新媒体运营', '商软冠联网络有限公司']
# ['韩荣', '女', 2013, 10, '运营', '传统运营', '高级传统运营', '浙大万朋网络有限公司']
# ['李桂荣', '女', 2008, 9, '设计', '原画', '特聘原画', '海创科技有限公司']
# ['梁桂芝', '男', 2001, 7, '开发', '平台开发', '高级平台开发', '同兴万点科技有限公司']
# ['何英', '女', 2003, 9, '测试', '白盒测试', '高级白盒测试', '凌云网络有限公司']
# ['吕雪', '男', 2016, 4, '运维', '数据库运维', '高级数据库运维', '创联世纪传媒有限公司']
# ['黎帆', '女', 2007, 5, '开发', '前端开发', '特聘前端开发', '时空盒数字科技有限公司']
# ['亓志强', '男', 2007, 2, '测试', '黑盒测试', '初级黑盒测试', '诺依曼软件传媒有限公司']
# ['刘玉珍', '男', 2005, 12, '管理', '公司领导', '特聘公司领导', '凌颖信息科技有限公司']
# ['陈金凤', '女', 2018, 2, '开发', '平台开发', '高级平台开发', '联软科技有限公司']
# ['陆玲', '男', 2018, 7, '财务', '出纳', '高级出纳', '联通时科信息有限公司']
# ['石文', '男', 2018, 3, '管理', '技术领导', '高级技术领导', '银嘉网络有限公司']
# ['张志强', '男', 2002, 7, '运营', '传统运营', '高级传统运营', '创联世纪网络有限公司']
# ['孙璐', '男', 2004, 4, '管理', '公司领导', '高级公司领导', '襄樊地球村传媒有限公司']
# ['马玲', '女', 2002, 8, '测试', '黑盒测试', '高级黑盒测试', '银嘉信息有限公司']
# ['李建军', '男', 2013, 7, '测试', '白盒测试', '特聘白盒测试', '巨奥信息有限公司']
# ['李淑珍', '男', 2014, 5, '运营', '新媒体运营', '高级新媒体运营', '快讯网络有限公司']
# ['王志强', '男', 2007, 3, '运营', '传统运营', '特聘传统运营', '迪摩传媒有限公司']
# ['梁帆', '女', 2012, 12, '设计', '原画', '高级原画', '艾提科信信息有限公司']
# ['冯玉兰', '男', 2007, 10, '运维', '数据库运维', '特聘数据库运维', '巨奥传媒有限公司']
# ['许雷', '女', 2010, 2, '测试', '白盒测试', '中级白盒测试', '新宇龙信息网络有限公司']
# ['雷伟', '女', 2010, 5, '运维', '服务器管理', '中级服务器管理', '毕博诚网络有限公司']
# ['王龙', '女', 2006, 8, '运营', '新媒体运营', '特聘新媒体运营', '立信电子传媒有限公司']
# ['黄成', '男', 2019, 12, '管理', '技术领导', '特聘技术领导', '维旺明信息有限公司']
# ['谢利', '女', 2019, 2, '运营', '新媒体运营', '特聘新媒体运营', '图龙信息科技有限公司']
# ['陈楠', '女', 2005, 2, '运维', '数据库运维', '特聘数据库运维', '群英传媒有限公司']
# ['陈娟', '男', 2014, 12, '测试', '白盒测试', '中级白盒测试', '雨林木风计算机信息有限公司']
# ['周丽华', '男', 2007, 3, '运维', '数据库运维', '中级数据库运维', '飞利信科技有限公司']
# ['龙淑华', '女', 2017, 4, '设计', '插画', '高级插画', '数字100科技有限公司']
# ['费华', '女', 2008, 3, '管理', '技术领导', '特聘技术领导', '联软传媒有限公司']
# ['余建军', '女', 2013, 7, '运营', '传统运营', '初级传统运营', '天开科技有限公司']
# ['朱欣', '女', 2014, 1, '开发', '后端开发', '高级后端开发', '方正科技传媒有限公司']
# ['刘丽娟', '女', 2013, 5, '测试', '黑盒测试', '特聘黑盒测试', '华成育卓网络有限公司']
# ['翁建国', '女', 2014, 11, '设计', '插画', '中级插画', '四通传媒有限公司']
# ['王凤英', '男', 2002, 1, '开发', '前端开发', '初级前端开发', '超艺信息有限公司']
# ['曹秀梅', '男', 2008, 6, '测试', '黑盒测试', '初级黑盒测试', '昊嘉网络有限公司']
# ['班博', '女', 2002, 10, '测试', '白盒测试', '初级白盒测试', '戴硕电子网络有限公司']
# ['潘刚', '男', 2017, 11, '开发', '后端开发', '特聘后端开发', '新格林耐特网络有限公司']
# ['徐敏', '男', 2016, 12, '设计', '原画', '特聘原画', '时空盒数字传媒有限公司']
# ['沈宁', '女', 2018, 3, '测试', '黑盒测试', '初级黑盒测试', '网新恒天信息有限公司']
# ['张兰英', '女', 2005, 2, '管理', '公司领导', '特聘公司领导', '昂歌信息网络有限公司']
# ['唐明', '男', 2010, 11, '财务', '会计', '高级会计', '菊风公司传媒有限公司']
# ['何淑英', '女', 2018, 8, '管理', '技术领导', '高级技术领导', '数字100信息有限公司']
# ['席莉', '女', 2014, 11, '管理', '技术领导', '中级技术领导', '开发区世创信息有限公司']
# ['吴桂兰', '男', 2015, 9, '运维', '服务器管理', '初级服务器管理', '维旺明网络有限公司']
# ['王华', '女', 2017, 5, '运维', '数据库运维', '高级数据库运维', '信诚致远信息有限公司']
# ['慕杰', '男', 2003, 7, '测试', '黑盒测试', '特聘黑盒测试', '商软冠联传媒有限公司']
# ['谭楠', '女', 2007, 6, '财务', '出纳', '特聘出纳', '迪摩信息有限公司']
# ['程荣', '男', 2005, 5, '设计', '原画', '特聘原画', '惠派国际公司传媒有限公司']
# ['刘成', '男', 2018, 10, '财务', '出纳', '初级出纳', '凌颖信息科技有限公司']
# ['骆莉', '女', 2001, 1, '测试', '黑盒测试', '初级黑盒测试', '毕博诚网络有限公司']
# ['徐海燕', '女', 2016, 5, '设计', '插画', '高级插画', '易动力网络有限公司']
# ['刘秀梅', '男', 2017, 7, '财务', '会计', '初级会计', '飞海科技传媒有限公司']
# ['相想', '男', 2016, 5, '财务', '出纳', '中级出纳', '彩虹科技有限公司']
# ['江英', '女', 2010, 7, '测试', '白盒测试', '特聘白盒测试', '昊嘉网络有限公司']
# ['莫超', '男', 2009, 4, '开发', '平台开发', '特聘平台开发', '网新恒天科技有限公司']
# ['张杰', '女', 2005, 9, '运维', '数据库运维', '特聘数据库运维', '菊风公司网络有限公司']
# ['马宇', '男', 2001, 10, '开发', '后端开发', '初级后端开发', '创联世纪传媒有限公司']
# ['张桂兰', '女', 2015, 6, '开发', '后端开发', '初级后端开发', '富罳信息有限公司']
# ['罗桂花', '女', 2012, 11, '设计', '插画', '特聘插画', '彩虹传媒有限公司']
# ['邢玉兰', '女', 2015, 3, '财务', '会计', '初级会计', '创汇网络有限公司']
# ['朱浩', '男', 2003, 11, '测试', '黑盒测试', '初级黑盒测试', '联软网络有限公司']
# ['陈兰英', '女', 2006, 5, '开发', '后端开发', '特聘后端开发', '创亿传媒有限公司']
# ['杨波', '男', 2014, 5, '运维', '数据库运维', '特聘数据库运维', '良诺网络有限公司']
# ['葛璐', '女', 2008, 9, '管理', '技术领导', '高级技术领导', '合联电子网络有限公司']
# ['柴彬', '女', 2019, 2, '运维', '数据库运维', '高级数据库运维', '创汇科技有限公司']
# ['钱兰英', '男', 2019, 2, '财务', '出纳', '特聘出纳', '彩虹科技有限公司']
# ['杨健', '男', 2006, 1, '开发', '平台开发', '中级平台开发', '盟新科技有限公司']
# ['王秀芳', '男', 2017, 8, '运营', '新媒体运营', '高级新媒体运营', '图龙信息传媒有限公司']
# ['高宁', '男', 2015, 7, '运维', '数据库运维', '特聘数据库运维', '信诚致远网络有限公司']
# ['王明', '男', 2002, 3, '开发', '前端开发', '中级前端开发', '东方峻景信息有限公司']
# ['曾想', '女', 2006, 4, '管理', '技术领导', '初级技术领导', '商软冠联科技有限公司']
# ['王宇', '男', 2011, 3, '财务', '会计', '初级会计', '东方峻景信息有限公司']
# ['杨俊', '女', 2010, 5, '财务', '会计', '高级会计', '彩虹科技有限公司']
# ['蔡杰', '男', 2015, 11, '设计', '插画', '中级插画', '明腾网络有限公司']
# ['乔帅', '男', 2015, 5, '财务', '出纳', '高级出纳', '恒聪百汇传媒有限公司']
# ['刘小红', '女', 2013, 10, '测试', '白盒测试', '初级白盒测试', '盟新网络有限公司']
# ['张宇', '男', 2004, 10, '开发', '平台开发', '初级平台开发', '万迅电脑网络有限公司']
# ['林楠', '男', 2010, 9, '运维', '数据库运维', '高级数据库运维', '天益信息有限公司']
# ['赵丽', '男', 2015, 1, '测试', '白盒测试', '特聘白盒测试', '群英网络有限公司']
# ['常洁', '女', 2002, 4, '管理', '技术领导', '高级技术领导', '迪摩传媒有限公司']
# ['刘桂芳', '男', 2017, 7, '设计', '插画', '高级插画', '昂歌信息传媒有限公司']
# ['张建', '男', 2019, 11, '设计', '插画', '高级插画', '群英传媒有限公司']
# ['周建平', '男', 2006, 10, '开发', '后端开发', '特聘后端开发', '时刻科技有限公司']
# ['翁春梅', '男', 2019, 4, '运维', '数据库运维', '中级数据库运维', '菊风公司信息有限公司']
# ['向超', '男', 2004, 2, '运维', '服务器管理', '中级服务器管理', '南康科技有限公司']
# ['王健', '男', 2018, 6, '测试', '黑盒测试', '初级黑盒测试', '通际名联信息有限公司']
# ['张雪梅', '男', 2013, 5, '运维', '服务器管理', '初级服务器管理', '恒聪百汇信息有限公司']
# ['张宁', '男', 2003, 5, '运维', '服务器管理', '中级服务器管理', '商软冠联科技有限公司']
# ['叶成', '男', 2005, 2, '设计', '原画', '特聘原画', '四通传媒有限公司']
# ['张玉珍', '男', 2008, 9, '财务', '出纳', '高级出纳', 'MBP软件信息有限公司']
# ['刘帆', '男', 2007, 10, '管理', '技术领导', '特聘技术领导', '趋势科技有限公司']
# ['冯飞', '男', 2008, 5, '开发', '平台开发', '高级平台开发', '商软冠联网络有限公司']
# ['文丹', '女', 2016, 11, '财务', '会计', '高级会计', '维涛传媒有限公司']
# ['涂柳', '女', 2012, 9, '测试', '白盒测试', '特聘白盒测试', '联通时科科技有限公司']
# ['刘晨', '女', 2006, 4, '设计', '插画', '初级插画', '雨林木风计算机信息有限公司']
# ['范利', '男', 2014, 9, '管理', '公司领导', '中级公司领导', '黄石金承科技有限公司']
# ['宋俊', '女', 2019, 9, '测试', '白盒测试', '特聘白盒测试', '思优网络有限公司']
# ['薛飞', '女', 2019, 12, '管理', '技术领导', '特聘技术领导', '巨奥传媒有限公司']
# ['李玉华', '男', 2013, 11, '运维', '服务器管理', '初级服务器管理', '商软冠联网络有限公司']
# ['高杨', '女', 2019, 10, '测试', '白盒测试', '特聘白盒测试', '盟新传媒有限公司']
# ['王秀华', '女', 2014, 4, '运维', '数据库运维', '初级数据库运维', '雨林木风计算机信息有限公司']
# ['王桂荣', '女', 2016, 4, '运营', '新媒体运营', '中级新媒体运营', '联软信息有限公司']
# ['高秀云', '男', 2004, 2, '测试', '白盒测试', '初级白盒测试', '凌云信息有限公司']
# ['李金凤', '男', 2015, 10, '财务', '会计', '高级会计', '精芯传媒有限公司']
# ['吕超', '女', 2014, 1, '运维', '服务器管理', '初级服务器管理', '凌颖信息传媒有限公司']
# ['王璐', '女', 2007, 12, '运营', '新媒体运营', '中级新媒体运营', '南康科技有限公司']
# ['宋丽娟', '男', 2008, 11, '设计', '插画', '中级插画', '立信电子网络有限公司']
# ['林东', '女', 2009, 5, '运营', '新媒体运营', '特聘新媒体运营', '济南亿次元信息有限公司']
# ['陈淑兰', '女', 2015, 4, '运营', '传统运营', '初级传统运营', '泰麒麟网络有限公司']
# ['萧玉', '女', 2013, 6, '测试', '白盒测试', '高级白盒测试', '和泰信息有限公司']
# ['韩玉梅', '男', 2010, 3, '测试', '黑盒测试', '初级黑盒测试', '鑫博腾飞信息有限公司']
# ['袁强', '女', 2005, 1, '开发', '前端开发', '初级前端开发', '迪摩传媒有限公司']
# ['尹辉', '男', 2012, 2, '管理', '技术领导', '高级技术领导', '黄石金承传媒有限公司']
# ['王阳', '男', 2004, 9, '开发', '平台开发', '初级平台开发', '时刻网络有限公司']
# ['张琴', '男', 2013, 1, '管理', '技术领导', '中级技术领导', '晖来计算机信息有限公司']
# ['张阳', '男', 2009, 4, '管理', '公司领导', '中级公司领导', '盟新网络有限公司']
# ['沈佳', '女', 2004, 10, '运维', '数据库运维', '高级数据库运维', '思优传媒有限公司']
# ['陈红', '女', 2005, 6, '运营', '新媒体运营', '初级新媒体运营', '银嘉信息有限公司']
# ['李秀云', '男', 2007, 2, '测试', '白盒测试', '中级白盒测试', '鑫博腾飞信息有限公司']
# ['蔡倩', '女', 2007, 11, '财务', '出纳', '初级出纳', '维旺明科技有限公司']
# ['陈琳', '男', 2004, 8, '运维', '服务器管理', '特聘服务器管理', '易动力传媒有限公司']
# ['杨鹏', '女', 2019, 10, '运营', '传统运营', '中级传统运营', '和泰信息有限公司']
# ['胡玉珍', '女', 2001, 3, '运维', '数据库运维', '高级数据库运维', '精芯科技有限公司']
# ['张东', '女', 2003, 2, '运营', '新媒体运营', '高级新媒体运营', '万迅电脑网络有限公司']
# ['王玉', '女', 2008, 8, '开发', '平台开发', '高级平台开发', '联软科技有限公司']
# ['罗鹏', '女', 2005, 3, '管理', '技术领导', '高级技术领导', '商软冠联网络有限公司']
# ['俞建国', '男', 2007, 7, '设计', '原画', '特聘原画', '创汇网络有限公司']
# ['成雪梅', '女', 2010, 11, '开发', '平台开发', '特聘平台开发', '思优网络有限公司']
# ['朱强', '男', 2013, 10, '管理', '公司领导', '中级公司领导', '戴硕电子科技有限公司']
# ['萧秀荣', '男', 2018, 3, '财务', '会计', '初级会计', '菊风公司网络有限公司']
# ['周冬梅', '男', 2008, 12, '设计', '插画', '高级插画', '海创科技有限公司']
# ['黄明', '男', 2018, 7, '管理', '技术领导', '特聘技术领导', '方正科技网络有限公司']
# ['徐桂香', '女', 2002, 11, '财务', '会计', '中级会计', '毕博诚信息有限公司']
# ['沈洁', '男', 2007, 11, '运营', '传统运营', '特聘传统运营', '鑫博腾飞科技有限公司']
# ['洪玉华', '女', 2006, 11, '开发', '前端开发', '特聘前端开发', '四通信息有限公司']
# ['李建华', '女', 2011, 8, '运维', '数据库运维', '特聘数据库运维', '惠派国际公司信息有限公司']
# ['刘凤英', '女', 2012, 1, '财务', '出纳', '特聘出纳', '国讯传媒有限公司']
# ['周鑫', '男', 2016, 1, '运维', '数据库运维', '中级数据库运维', '天益科技有限公司']
# ['宋荣', '男', 2004, 1, '财务', '会计', '初级会计', '鸿睿思博传媒有限公司']
# ['王玉', '男', 2012, 9, '开发', '前端开发', '中级前端开发', '佳禾信息有限公司']
# ['崔静', '女', 2008, 10, '运营', '新媒体运营', '中级新媒体运营', '趋势传媒有限公司']
# ['焦玉珍', '男', 2019, 4, '管理', '技术领导', '特聘技术领导', '商软冠联网络有限公司']
# ['李梅', '女', 2011, 10, '测试', '黑盒测试', '中级黑盒测试', '富罳科技有限公司']
# ['王红霞', '女', 2007, 9, '设计', '原画', '高级原画', '联通时科科技有限公司']
# ['陈洋', '男', 2015, 12, '财务', '会计', '中级会计', '东方峻景科技有限公司']
# ['吴佳', '女', 2009, 11, '财务', '出纳', '特聘出纳', '通际名联网络有限公司']
# ['林娜', '男', 2005, 1, '测试', '黑盒测试', '高级黑盒测试', '恩悌信息有限公司']
# ['邵桂英', '女', 2005, 9, '运维', '服务器管理', '初级服务器管理', '良诺信息有限公司']
# ['李彬', '女', 2001, 3, '管理', '公司领导', '高级公司领导', '昊嘉信息有限公司']
# ['田桂英', '男', 2018, 7, '运维', '数据库运维', '特聘数据库运维', 'MBP软件科技有限公司']
# ['魏丹丹', '男', 2010, 6, '设计', '插画', '特聘插画', '凌云传媒有限公司']
# ['杨凤英', '女', 2018, 2, '开发', '后端开发', '中级后端开发', '图龙信息信息有限公司']
# ['聂涛', '女', 2017, 12, '管理', '技术领导', '初级技术领导', '飞海科技网络有限公司']
# ['高帆', '男', 2006, 2, '运营', '传统运营', '中级传统运营', '浙大万朋传媒有限公司']
# ['白桂兰', '男', 2014, 1, '管理', '公司领导', '初级公司领导', '华成育卓科技有限公司']
# ['张欣', '女', 2008, 12, '管理', '公司领导', '初级公司领导', '趋势网络有限公司']
# ['许波', '女', 2018, 2, '设计', '插画', '初级插画', '中建创业科技有限公司']
# ['梁建华', '男', 2019, 12, '运维', '服务器管理', '初级服务器管理', '精芯传媒有限公司']
# ['郝建军', '女', 2004, 2, '管理', '技术领导', '中级技术领导', '飞利信传媒有限公司']
# ['邓楠', '男', 2003, 2, '设计', '插画', '特聘插画', '天益网络有限公司']
# ['李敏', '男', 2017, 10, '测试', '黑盒测试', '高级黑盒测试', '飞利信网络有限公司']
# ['蔡梅', '女', 2019, 3, '财务', '会计', '特聘会计', '精芯网络有限公司']
# ['高伟', '女', 2009, 6, '开发', '平台开发', '特聘平台开发', '维涛传媒有限公司']
# ['刘东', '男', 2017, 11, '运维', '数据库运维', '特聘数据库运维', '鸿睿思博传媒有限公司']
# ['宋颖', '女', 2003, 1, '运营', '传统运营', '高级传统运营', '九方科技有限公司']
# ['程丽华', '男', 2007, 2, '运维', '服务器管理', '中级服务器管理', '新宇龙信息信息有限公司']
# ['何楠', '男', 2010, 2, '管理', '技术领导', '高级技术领导', '中建创业传媒有限公司']
# ['宋红梅', '女', 2019, 3, '测试', '白盒测试', '初级白盒测试', '迪摩信息有限公司']
# ['汪桂花', '男', 2019, 9, '测试', '白盒测试', '特聘白盒测试', '雨林木风计算机传媒有限公司']
# ['康柳', '男', 2007, 5, '运维', '服务器管理', '高级服务器管理', '新格林耐特传媒有限公司']
# ['王晨', '男', 2011, 6, '开发', '平台开发', '中级平台开发', '新格林耐特科技有限公司']
# ['陈文', '女', 2009, 12, '测试', '黑盒测试', '特聘黑盒测试', '天开网络有限公司']
# ['马欣', '男', 2008, 6, '运维', '服务器管理', '中级服务器管理', '开发区世创信息有限公司']
# ['余丽', '女', 2001, 10, '管理', '技术领导', '中级技术领导', '恩悌信息有限公司']
# ['何林', '女', 2014, 5, '财务', '会计', '高级会计', '万迅电脑传媒有限公司']
# ['杜鑫', '女', 2018, 3, '设计', '原画', '特聘原画', '群英信息有限公司']
# ['朱玉英', '女', 2004, 3, '设计', '插画', '初级插画', '天益科技有限公司']
# ['姚晨', '男', 2002, 3, '管理', '公司领导', '中级公司领导', '菊风公司传媒有限公司']
# ['傅艳', '男', 2012, 5, '财务', '出纳', '高级出纳', '银嘉信息有限公司']
# ['王淑兰', '女', 2004, 12, '运营', '新媒体运营', '中级新媒体运营', '双敏电子科技有限公司']
# ['江健', '男', 2012, 4, '开发', '前端开发', '高级前端开发', '济南亿次元网络有限公司']
# ['田桂芳', '女', 2004, 12, '测试', '黑盒测试', '中级黑盒测试', '东方峻景信息有限公司']
# ['赵淑华', '女', 2005, 11, '测试', '白盒测试', '高级白盒测试', '佳禾科技有限公司']
# ['李璐', '男', 2007, 11, '管理', '公司领导', '特聘公司领导', '毕博诚信息有限公司']
# ['王秀珍', '女', 2011, 5, '设计', '插画', '高级插画', '合联电子网络有限公司']
# ['瞿淑华', '男', 2003, 6, '开发', '平台开发', '高级平台开发', '兰金电子信息有限公司']
# ['陈芳', '男', 2001, 1, '运维', '数据库运维', '特聘数据库运维', '南康信息有限公司']
# ['罗宁', '女', 2009, 12, '财务', '出纳', '初级出纳', '立信电子传媒有限公司']
# ['刘海燕', '男', 2019, 2, '测试', '黑盒测试', '初级黑盒测试', '飞利信传媒有限公司']
# ['彭海燕', '女', 2007, 4, '测试', '白盒测试', '初级白盒测试', '创联世纪信息有限公司']
# ['邱桂珍', '男', 2013, 12, '运营', '新媒体运营', '特聘新媒体运营', '立信电子网络有限公司']
# ['赵秀兰', '男', 2002, 4, '运维', '数据库运维', '初级数据库运维', '开发区世创网络有限公司']
# ['胡丹', '男', 2013, 4, '设计', '插画', '特聘插画', '浦华众城传媒有限公司']
# ['林洋', '女', 2018, 10, '管理', '公司领导', '初级公司领导', '迪摩信息有限公司']
# ['吴坤', '女', 2018, 5, '测试', '白盒测试', '中级白盒测试', '快讯传媒有限公司']
# ['史玉华', '男', 2008, 1, '运营', '新媒体运营', '初级新媒体运营', '太极网络有限公司']
# ['李建', '男', 2006, 10, '运维', '数据库运维', '中级数据库运维', '时空盒数字传媒有限公司']
# ['田琳', '男', 2013, 8, '开发', '后端开发', '特聘后端开发', '巨奥网络有限公司']
# ['林俊', '男', 2007, 8, '测试', '白盒测试', '高级白盒测试', '信诚致远网络有限公司']
# ['张兵', '男', 2004, 8, '设计', '原画', '中级原画', '合联电子传媒有限公司']
# ['王文', '女', 2008, 8, '管理', '公司领导', '中级公司领导', '新格林耐特网络有限公司']
# ['王楠', '女', 2016, 7, '运营', '新媒体运营', '中级新媒体运营', '快讯网络有限公司']
# ['李桂荣', '男', 2009, 10, '运营', '传统运营', '特聘传统运营', '新宇龙信息信息有限公司']
# ['农莹', '男', 2001, 3, '运维', '数据库运维', '中级数据库运维', '快讯传媒有限公司']
# ['贺宇', '男', 2012, 10, '运维', '服务器管理', '初级服务器管理', '网新恒天传媒有限公司']
# ['张霞', '女', 2011, 9, '运营', '新媒体运营', '中级新媒体运营', '明腾网络有限公司']
# ['苏海燕', '男', 2005, 5, '管理', '技术领导', '高级技术领导', '创汇传媒有限公司']
# ['吴桂芝', '男', 2014, 2, '财务', '会计', '特聘会计', '七喜信息有限公司']
# ['王磊', '男', 2007, 11, '运维', '数据库运维', '特聘数据库运维', '彩虹传媒有限公司']
# ['吴英', '男', 2004, 3, '测试', '白盒测试', '中级白盒测试', '襄樊地球村科技有限公司']
# ['郭云', '女', 2016, 1, '财务', '出纳', '特聘出纳', '凌颖信息信息有限公司']
# ['陈玲', '男', 2009, 12, '开发', '后端开发', '中级后端开发', '飞海科技科技有限公司']
# ['范柳', '女', 2013, 1, '设计', '插画', '中级插画', '易动力科技有限公司']
# ['龚丽娟', '女', 2012, 2, '开发', '前端开发', '初级前端开发', '富罳信息有限公司']
# ['鞠娟', '女', 2003, 12, '开发', '前端开发', '中级前端开发', '迪摩信息有限公司']
# ['易秀芳', '女', 2003, 5, '开发', '后端开发', '初级后端开发', '浙大万朋信息有限公司']
# ['杨博', '女', 2002, 2, '管理', '公司领导', '中级公司领导', '盟新科技有限公司']
# ['王小红', '男', 2016, 8, '运营', '传统运营', '高级传统运营', '浙大万朋科技有限公司']
# ['冯桂花', '男', 2009, 4, '运营', '传统运营', '中级传统运营', '双敏电子科技有限公司']
# ['郑云', '女', 2007, 1, '设计', '原画', '初级原画', '创联世纪科技有限公司']
# ['刘玉华', '女', 2007, 5, '财务', '会计', '初级会计', '佳禾科技有限公司']
# ['李婷', '男', 2019, 4, '开发', '后端开发', '特聘后端开发', '双敏电子信息有限公司']
# ['罗小红', '女', 2012, 12, '管理', '技术领导', '初级技术领导', '易动力科技有限公司']
# ['吴秀珍', '男', 2011, 6, '财务', '会计', '高级会计', '易动力科技有限公司']
# ['倪玉梅', '女', 2017, 6, '运维', '服务器管理', '特聘服务器管理', '明腾网络有限公司']
# ['吴俊', '女', 2015, 5, '财务', '会计', '中级会计', '七喜网络有限公司']
# ['王秀芳', '女', 2005, 12, '运维', '服务器管理', '中级服务器管理', '华成育卓科技有限公司']
# ['朱娟', '男', 2009, 12, '管理', '技术领导', '特聘技术领导', '商软冠联信息有限公司']
# ['温玉华', '女', 2003, 8, '运维', '服务器管理', '中级服务器管理', '快讯网络有限公司']
# ['贺秀梅', '女', 2016, 6, '运营', '新媒体运营', '高级新媒体运营', '太极科技有限公司']
# ['顾荣', '女', 2014, 2, '运营', '新媒体运营', '初级新媒体运营', '迪摩传媒有限公司']
# ['张洁', '女', 2003, 1, '财务', '出纳', '高级出纳', '菊风公司传媒有限公司']
# ['张鹏', '男', 2002, 2, '财务', '会计', '高级会计', '信诚致远信息有限公司']
# ['赵浩', '男', 2002, 6, '运维', '服务器管理', '高级服务器管理', '诺依曼软件传媒有限公司']
# ['唐红', '女', 2003, 6, '管理', '技术领导', '中级技术领导', '思优传媒有限公司']
# ['杨桂兰', '男', 2009, 6, '运维', '服务器管理', '中级服务器管理', '九方科技有限公司']
# ['沈建华', '男', 2003, 9, '设计', '插画', '特聘插画', '恩悌信息有限公司']
# ['方慧', '女', 2011, 8, '管理', '公司领导', '特聘公司领导', '巨奥网络有限公司']
# ['陈桂花', '女', 2002, 5, '运营', '传统运营', '特聘传统运营', '飞利信信息有限公司']
# ['边军', '女', 2002, 10, '设计', '原画', '中级原画', '创联世纪科技有限公司']
# ['王彬', '男', 2017, 7, '运维', '数据库运维', '高级数据库运维', '济南亿次元传媒有限公司']
# ['林强', '女', 2002, 7, '设计', '原画', '初级原画', '明腾网络有限公司']
# ['蒋玉', '女', 2016, 4, '财务', '会计', '高级会计', '雨林木风计算机科技有限公司']
# ['陈成', '女', 2010, 10, '管理', '技术领导', '高级技术领导', '联通时科科技有限公司']
# ['何勇', '男', 2004, 4, '测试', '白盒测试', '特聘白盒测试', '银嘉网络有限公司']
# ['赵萍', '男', 2011, 9, '财务', '出纳', '初级出纳', '中建创业传媒有限公司']
# ['刘秀兰', '男', 2009, 7, '设计', '插画', '特聘插画', '南康网络有限公司']
# ['王洁', '男', 2019, 12, '测试', '白盒测试', '中级白盒测试', '通际名联网络有限公司']
# ['王旭', '女', 2002, 2, '测试', '黑盒测试', '初级黑盒测试', '创汇传媒有限公司']
# ['郝敏', '男', 2017, 2, '测试', '白盒测试', '特聘白盒测试', '七喜信息有限公司']
# ['赵欣', '女', 2014, 10, '财务', '会计', '特聘会计', '超艺网络有限公司']
# ['管磊', '女', 2011, 11, '开发', '后端开发', '高级后端开发', '数字100传媒有限公司']
# ['董瑞', '女', 2015, 10, '管理', '公司领导', '特聘公司领导', '鸿睿思博信息有限公司']
# ['王飞', '女', 2012, 1, '运维', '数据库运维', '初级数据库运维', '富罳科技有限公司']
# ['马莹', '男', 2018, 2, '财务', '会计', '高级会计', '盟新科技有限公司']
# ['陈梅', '男', 2008, 3, '设计', '原画', '初级原画', '同兴万点网络有限公司']
# ['王冬梅', '男', 2017, 9, '设计', '原画', '特聘原画', '万迅电脑传媒有限公司']
# ['刘辉', '男', 2001, 6, '开发', '前端开发', '初级前端开发', '昊嘉网络有限公司']
# ['李彬', '男', 2018, 8, '设计', '插画', '中级插画', '黄石金承传媒有限公司']
# ['张淑兰', '男', 2005, 8, '财务', '出纳', '特聘出纳', '网新恒天传媒有限公司']
# ['林桂英', '女', 2013, 9, '管理', '技术领导', '特聘技术领导', '泰麒麟传媒有限公司']
# ['朱斌', '女', 2012, 12, '开发', '后端开发', '中级后端开发', '艾提科信网络有限公司']
# ['杨凤英', '女', 2014, 4, '运营', '传统运营', '高级传统运营', '毕博诚网络有限公司']
# ['赵玉华', '男', 2014, 5, '设计', '插画', '特聘插画', '群英科技有限公司']
# ['李宁', '男', 2018, 2, '财务', '会计', '高级会计', '襄樊地球村传媒有限公司']
# ['陈静', '女', 2019, 9, '财务', '出纳', '特聘出纳', '信诚致远传媒有限公司']
# ['鲍晨', '男', 2006, 8, '运维', '数据库运维', '特聘数据库运维', '九方网络有限公司']
# ['陈欢', '男', 2006, 9, '管理', '公司领导', '初级公司领导', '泰麒麟传媒有限公司']
# ['胡勇', '男', 2014, 11, '运营', '传统运营', '特聘传统运营', '浦华众城信息有限公司']
# ['贾建国', '女', 2019, 11, '运营', '新媒体运营', '特聘新媒体运营', '万迅电脑信息有限公司']
# ['娄霞', '男', 2007, 6, '运维', '服务器管理', '中级服务器管理', '凌颖信息科技有限公司']
# ['乔莹', '女', 2013, 9, '测试', '黑盒测试', '初级黑盒测试', '艾提科信科技有限公司']
# ['曾兵', '女', 2008, 6, '测试', '黑盒测试', '特聘黑盒测试', '创汇科技有限公司']
# ['丁桂芝', '男', 2006, 11, '管理', '公司领导', '初级公司领导', '七喜网络有限公司']
# ['张鑫', '男', 2014, 5, '设计', '原画', '特聘原画', '彩虹网络有限公司']
# ['郭秀云', '男', 2002, 11, '运营', '新媒体运营', '中级新媒体运营', '东方峻景传媒有限公司']
# ['梁桂芝', '男', 2006, 3, '测试', '黑盒测试', '特聘黑盒测试', '时空盒数字科技有限公司']
# ['李杰', '男', 2016, 9, '设计', '插画', '特聘插画', '创亿传媒有限公司']
# ['邵阳', '女', 2019, 8, '开发', '平台开发', '特聘平台开发', '泰麒麟传媒有限公司']
# ['常磊', '男', 2014, 1, '管理', '公司领导', '特聘公司领导', '创汇网络有限公司']
# ['段建国', '男', 2004, 5, '测试', '黑盒测试', '高级黑盒测试', '富罳网络有限公司']
# ['姜伟', '男', 2013, 1, '管理', '公司领导', '初级公司领导', '艾提科信网络有限公司']
# ['张娜', '男', 2014, 10, '管理', '技术领导', '中级技术领导', '易动力科技有限公司']
# ['孙飞', '男', 2002, 2, '运营', '传统运营', '特聘传统运营', '四通信息有限公司']
# ['苏军', '女', 2003, 10, '设计', '插画', '特聘插画', '维旺明网络有限公司']
# ['刘桂芝', '男', 2008, 1, '运营', '新媒体运营', '高级新媒体运营', '快讯传媒有限公司']
# ['王敏', '女', 2019, 11, '运营', '传统运营', '特聘传统运营', '浦华众城传媒有限公司']
# ['汪洋', '女', 2002, 5, '运维', '数据库运维', '高级数据库运维', '昊嘉信息有限公司']
# ['钟凤兰', '男', 2002, 2, '财务', '会计', '高级会计', '济南亿次元科技有限公司']
# ['刘博', '男', 2009, 12, '设计', '原画', '特聘原画', '九方信息有限公司']
# ['朱华', '男', 2003, 7, '设计', '插画', '初级插画', '立信电子信息有限公司']
# ['曾红梅', '女', 2012, 1, '运维', '服务器管理', '高级服务器管理', '时刻网络有限公司']
# ['李俊', '女', 2003, 6, '测试', '白盒测试', '高级白盒测试', '时空盒数字科技有限公司']
# ['金凤英', '女', 2010, 9, '运营', '传统运营', '中级传统运营', '艾提科信信息有限公司']
# ['张俊', '男', 2003, 9, '管理', '公司领导', '高级公司领导', '四通信息有限公司']
# ['何宇', '男', 2019, 4, '开发', '后端开发', '中级后端开发', '同兴万点信息有限公司']
# ['齐健', '男', 2002, 11, '设计', '插画', '高级插画', '浙大万朋网络有限公司']
# ['赖瑜', '女', 2014, 2, '财务', '出纳', '中级出纳', '合联电子网络有限公司']
# ['秦刚', '男', 2019, 9, '财务', '会计', '高级会计', '飞利信信息有限公司']
# ['王杰', '男', 2012, 11, '测试', '白盒测试', '初级白盒测试', '超艺网络有限公司']
# ['苏玲', '男', 2006, 5, '测试', '白盒测试', '高级白盒测试', '双敏电子科技有限公司']
# ['王飞', '男', 2008, 3, '管理', '公司领导', '初级公司领导', '和泰信息有限公司']
# ['梁欣', '男', 2008, 1, '运营', '新媒体运营', '中级新媒体运营', '鑫博腾飞科技有限公司']
# ['王明', '男', 2018, 3, '设计', '插画', '高级插画', '华成育卓网络有限公司']
# ['孙晨', '男', 2016, 9, '运营', '新媒体运营', '特聘新媒体运营', '富罳传媒有限公司']
# ['钱磊', '男', 2013, 10, '设计', '插画', '特聘插画', '富罳传媒有限公司']
# ['郑淑英', '男', 2010, 10, '管理', '公司领导', '特聘公司领导', '通际名联信息有限公司']
# ['朱凯', '男', 2013, 4, '测试', '白盒测试', '高级白盒测试', '维旺明科技有限公司']
# ['陈建国', '女', 2013, 3, '运维', '数据库运维', '中级数据库运维', '天益科技有限公司']
# ['杨华', '女', 2016, 2, '开发', '前端开发', '特聘前端开发', '七喜传媒有限公司']
# ['余璐', '女', 2008, 10, '测试', '黑盒测试', '初级黑盒测试', '南康科技有限公司']
# ['张倩', '女', 2017, 3, '测试', '黑盒测试', '初级黑盒测试', '恩悌科技有限公司']
# ['倪志强', '女', 2009, 4, '运维', '数据库运维', '特聘数据库运维', '菊风公司科技有限公司']
# ['郑东', '男', 2018, 7, '开发', '后端开发', '中级后端开发', 'MBP软件网络有限公司']
# ...
# ['汪健', '女', 2008, 7, '测试', '白盒测试', '初级白盒测试', '菊风公司科技有限公司']
# ['陈想', '女', 2001, 5, '运维', '数据库运维', '高级数据库运维', '易动力传媒有限公司']
# ['朱桂荣', '男', 2008, 11, '财务', '出纳', '中级出纳', '新格林耐特传媒有限公司']
# ['左明', '女', 2004, 2, '测试', '白盒测试', '特聘白盒测试', '雨林木风计算机网络有限公司']
# ['王彬', '女', 2016, 2, '设计', '插画', '初级插画', '浦华众城信息有限公司']
# ['胡桂荣', '男', 2003, 2, '运维', '服务器管理', '高级服务器管理', '凌颖信息网络有限公司']
# ['廖玉华', '女', 2015, 9, '运营', '传统运营', '高级传统运营', '联通时科科技有限公司']
# ['王秀云', '男', 2019, 7, '财务', '出纳', '中级出纳', '开发区世创传媒有限公司']
# ['王玉华', '女', 2007, 2, '运维', '服务器管理', '特聘服务器管理', '彩虹信息有限公司']
# ['赵瑜', '女', 2018, 9, '管理', '公司领导', '初级公司领导', '戴硕电子网络有限公司']
# ['刘磊', '女', 2015, 2, '管理', '技术领导', '特聘技术领导', '艾提科信传媒有限公司']
# ['尚志强', '男', 2004, 4, '运营', '传统运营', '初级传统运营', '创联世纪科技有限公司']
# ['徐淑兰', '男', 2018, 11, '设计', '原画', '特聘原画', '联通时科传媒有限公司']
# ['李晨', '男', 2002, 1, '运维', '数据库运维', '初级数据库运维', '易动力传媒有限公司']
# ['孙淑珍', '男', 2014, 3, '运营', '新媒体运营', '高级新媒体运营', '恩悌科技有限公司']
# ['苏杰', '女', 2017, 12, '财务', '出纳', '高级出纳', '良诺网络有限公司']
# ['尤建平', '男', 2008, 11, '开发', '后端开发', '特聘后端开发', '华泰通安传媒有限公司']
# ['傅雷', '女', 2013, 5, '运维', '数据库运维', '初级数据库运维', '东方峻景网络有限公司']
# ['王倩', '女', 2018, 9, '开发', '后端开发', '中级后端开发', '双敏电子科技有限公司']
# ['成宇', '女', 2013, 1, '财务', '出纳', '中级出纳', '创亿网络有限公司']
# ['黄冬梅', '女', 2017, 2, '测试', '黑盒测试', '高级黑盒测试', '襄樊地球村科技有限公司']
# ['赵秀荣', '女', 2003, 12, '管理', '公司领导', '特聘公司领导', '精芯信息有限公司']
# ['杨峰', '男', 2004, 2, '测试', '白盒测试', '初级白盒测试', '同兴万点信息有限公司']
# ['王雪梅', '女', 2005, 4, '运维', '数据库运维', '初级数据库运维', '创联世纪传媒有限公司']
# ['王坤', '男', 2014, 12, '财务', '出纳', '初级出纳', '飞利信信息有限公司']
# ['林红', '男', 2018, 3, '运营', '新媒体运营', '中级新媒体运营', '商软冠联信息有限公司']
# ['陈伟', '男', 2016, 9, '设计', '插画', '中级插画', '佳禾科技有限公司']
# ['涂阳', '男', 2012, 10, '测试', '黑盒测试', '初级黑盒测试', '惠派国际公司信息有限公司']
# ['李涛', '女', 2008, 8, '测试', '白盒测试', '初级白盒测试', '海创网络有限公司']
# ['徐桂荣', '女', 2006, 6, '财务', '出纳', '高级出纳', '联通时科信息有限公司']
# ['庄成', '女', 2010, 8, '设计', '原画', '中级原画', '时刻传媒有限公司']
# ['李飞', '女', 2016, 6, '设计', '插画', '中级插画', '恒聪百汇科技有限公司']
# ['陈磊', '男', 2007, 2, '运营', '传统运营', '中级传统运营', '恒聪百汇科技有限公司']
# ['熊鑫', '男', 2005, 5, '设计', '插画', '高级插画', '精芯科技有限公司']
# ['孟慧', '女', 2012, 7, '财务', '出纳', '中级出纳', '恒聪百汇传媒有限公司']
# ['周金凤', '男', 2003, 2, '测试', '黑盒测试', '初级黑盒测试', '毕博诚信息有限公司']
# ['白凯', '男', 2003, 9, '测试', '白盒测试', '高级白盒测试', '凌颖信息科技有限公司']
# ['王红霞', '女', 2014, 4, '设计', '插画', '特聘插画', '昊嘉传媒有限公司']
# ['郑玲', '女', 2002, 5, '运维', '服务器管理', '高级服务器管理', '凌颖信息传媒有限公司']
# ['罗洋', '男', 2011, 2, '财务', '出纳', '初级出纳', '天开网络有限公司']
# ['朱宁', '男', 2004, 10, '运营', '新媒体运营', '初级新媒体运营', '雨林木风计算机传媒有限公司']
# ['温华', '女', 2017, 10, '运营', '新媒体运营', '中级新媒体运营', '泰麒麟信息有限公司']
# ['张金凤', '男', 2004, 11, '运营', '传统运营', '中级传统运营', '时空盒数字信息有限公司']
# ['魏阳', '男', 2010, 4, '管理', '公司领导', '高级公司领导', '万迅电脑传媒有限公司']
# ['李萍', '男', 2001, 2, '设计', '插画', '中级插画', '易动力科技有限公司']
# ['刘想', '女', 2015, 12, '运维', '数据库运维', '高级数据库运维', '易动力网络有限公司']
# ['陈林', '女', 2018, 8, '财务', '出纳', '特聘出纳', '菊风公司科技有限公司']
# ['马兵', '女', 2017, 3, '测试', '白盒测试', '中级白盒测试', '国讯传媒有限公司']
# ['张莹', '男', 2012, 2, '开发', '后端开发', '中级后端开发', '恩悌网络有限公司']
# ['王建', '男', 2014, 7, '管理', '公司领导', '高级公司领导', '通际名联网络有限公司']
# ['俞洋', '男', 2007, 10, '设计', '原画', '中级原画', '合联电子网络有限公司']
# ['郭丽华', '男', 2015, 4, '运营', '新媒体运营', '初级新媒体运营', '晖来计算机科技有限公司']
# ['贾玉梅', '男', 2008, 9, '设计', '插画', '中级插画', '同兴万点信息有限公司']
# ['孙华', '男', 2005, 9, '财务', '会计', '初级会计', '时空盒数字网络有限公司']
# ['刘浩', '女', 2016, 9, '设计', '插画', '特聘插画', '信诚致远信息有限公司']
# ['李秀云', '男', 2011, 2, '财务', '会计', '初级会计', '时刻科技有限公司']
# ['萧红梅', '男', 2016, 4, '管理', '公司领导', '特聘公司领导', '创亿信息有限公司']
# ['卞飞', '女', 2006, 12, '运维', '服务器管理', '初级服务器管理', '济南亿次元传媒有限公司']
# ['曾军', '男', 2018, 5, '运维', '服务器管理', '初级服务器管理', '恩悌信息有限公司']
# ['余鑫', '女', 2005, 7, '运维', '数据库运维', '高级数据库运维', '惠派国际公司传媒有限公司']
# ['萧红霞', '男', 2017, 2, '设计', '原画', '高级原画', '合联电子科技有限公司']
# ['钟涛', '女', 2003, 10, '财务', '出纳', '初级出纳', '昂歌信息网络有限公司']
# ['徐云', '女', 2013, 9, '管理', '技术领导', '中级技术领导', '九方科技有限公司']
# ['穆艳', '男', 2010, 4, '开发', '后端开发', '特聘后端开发', '创亿传媒有限公司']
# ['黄红', '男', 2002, 1, '管理', '技术领导', '特聘技术领导', '雨林木风计算机信息有限公司']
# ['李秀芳', '男', 2017, 10, '运维', '服务器管理', '初级服务器管理', '同兴万点信息有限公司']
# ['夏林', '女', 2005, 6, '财务', '会计', '中级会计', '中建创业网络有限公司']
# ['韩兰英', '男', 2016, 3, '运营', '传统运营', '初级传统运营', '毕博诚科技有限公司']
# ['张东', '男', 2013, 5, '管理', '技术领导', '特聘技术领导', '银嘉网络有限公司']
# ['任建军', '女', 2006, 4, '运维', '服务器管理', '中级服务器管理', '黄石金承科技有限公司']
# ['祝勇', '女', 2016, 1, '管理', '技术领导', '初级技术领导', '四通传媒有限公司']
# ['侯莹', '女', 2007, 4, '管理', '公司领导', '高级公司领导', '图龙信息科技有限公司']
# ['丁桂花', '男', 2019, 12, '管理', '公司领导', '特聘公司领导', '群英传媒有限公司']
# ['李涛', '男', 2003, 11, '管理', '公司领导', '初级公司领导', '彩虹传媒有限公司']
# ['韦雪梅', '女', 2008, 12, '运维', '服务器管理', '初级服务器管理', '同兴万点信息有限公司']
# ['王杰', '女', 2016, 3, '设计', '原画', '初级原画', '信诚致远科技有限公司']
# ['冯斌', '女', 2019, 7, '运营', '新媒体运营', '高级新媒体运营', '新格林耐特传媒有限公司']
# ['侯玉', '男', 2008, 3, '测试', '白盒测试', '特聘白盒测试', '信诚致远科技有限公司']
# ['韦红', '女', 2003, 5, '管理', '技术领导', '中级技术领导', '凌云网络有限公司']
# ['董欣', '男', 2003, 8, '测试', '白盒测试', '中级白盒测试', '南康科技有限公司']
# ['严俊', '男', 2005, 5, '设计', '插画', '初级插画', '信诚致远传媒有限公司']
# ['邬凤英', '男', 2009, 9, '管理', '公司领导', '高级公司领导', '黄石金承网络有限公司']
# ['黄岩', '男', 2003, 3, '管理', '公司领导', '特聘公司领导', '时空盒数字科技有限公司']
# ['卢刚', '男', 2007, 6, '开发', '后端开发', '特聘后端开发', '七喜科技有限公司']
# ['刘建', '男', 2009, 2, '测试', '黑盒测试', '初级黑盒测试', '盟新传媒有限公司']
# ['蔡霞', '女', 2015, 9, '开发', '后端开发', '高级后端开发', '明腾科技有限公司']
# ['涂林', '女', 2001, 5, '运维', '服务器管理', '初级服务器管理', '立信电子网络有限公司']
# ['曾成', '女', 2001, 9, '运维', '服务器管理', '高级服务器管理', '盟新传媒有限公司']
# ['张阳', '男', 2015, 11, '测试', '黑盒测试', '中级黑盒测试', '信诚致远科技有限公司']
# ['罗建军', '男', 2002, 8, '设计', '插画', '中级插画', '商软冠联信息有限公司']
# ['朱明', '男', 2017, 4, '开发', '平台开发', '高级平台开发', '维旺明网络有限公司']
# ['黄淑珍', '女', 2002, 8, '运维', '服务器管理', '高级服务器管理', '诺依曼软件网络有限公司']
# ['李云', '男', 2009, 10, '运维', '数据库运维', '中级数据库运维', '东方峻景传媒有限公司']
# ['姚旭', '男', 2001, 12, '开发', '前端开发', '高级前端开发', '昊嘉科技有限公司']
# ['鲍娜', '男', 2005, 4, '运维', '数据库运维', '高级数据库运维', '佳禾传媒有限公司']
# ['陈莉', '女', 2004, 1, '运维', '服务器管理', '高级服务器管理', '诺依曼软件网络有限公司']
# ['袁红梅', '男', 2007, 6, '设计', '插画', '初级插画', '时空盒数字科技有限公司']
# ['张桂芳', '女', 2014, 1, '运维', '服务器管理', '特聘服务器管理', '九方传媒有限公司']
# ['姜丽', '男', 2011, 6, '测试', '黑盒测试', '特聘黑盒测试', '恩悌信息有限公司']
# ['李玉梅', '男', 2017, 4, '开发', '前端开发', '初级前端开发', '合联电子信息有限公司']
# ['李雷', '男', 2001, 11, '设计', '原画', '中级原画', '思优网络有限公司']
# ['栗秀芳', '男', 2012, 9, '开发', '平台开发', '高级平台开发', '兰金电子网络有限公司']
# ['司雷', '女', 2019, 10, '管理', '公司领导', '高级公司领导', '开发区世创网络有限公司']
# ['郭浩', '女', 2003, 2, '测试', '白盒测试', '高级白盒测试', '方正科技网络有限公司']
# ['郑峰', '女', 2006, 9, '运维', '服务器管理', '高级服务器管理', '创亿科技有限公司']
# ['马晨', '女', 2004, 9, '测试', '黑盒测试', '中级黑盒测试', '四通信息有限公司']
# ['陈林', '女', 2004, 11, '运维', '服务器管理', '特聘服务器管理', '恒聪百汇科技有限公司']
# ['李波', '女', 2009, 7, '财务', '出纳', '初级出纳', '鸿睿思博网络有限公司']
# ['张琴', '男', 2014, 10, '管理', '公司领导', '高级公司领导', '飞海科技信息有限公司']
# ['林秀云', '女', 2007, 5, '测试', '黑盒测试', '特聘黑盒测试', '联软信息有限公司']
# ['谢萍', '男', 2014, 10, '测试', '黑盒测试', '中级黑盒测试', '恒聪百汇科技有限公司']
# ['金斌', '女', 2012, 7, '管理', '技术领导', '高级技术领导', '晖来计算机网络有限公司']
# ['李凤兰', '女', 2011, 4, '运营', '新媒体运营', '初级新媒体运营', '思优网络有限公司']
# ['郭旭', '女', 2011, 12, '运维', '数据库运维', '初级数据库运维', '信诚致远信息有限公司']
# ['齐建国', '女', 2007, 2, '财务', '会计', '初级会计', '襄樊地球村科技有限公司']
# ['郑丽娟', '男', 2016, 6, '运营', '传统运营', '中级传统运营', '双敏电子传媒有限公司']
# ['刘梅', '女', 2017, 1, '管理', '技术领导', '中级技术领导', '新宇龙信息信息有限公司']
# ['贾秀梅', '男', 2019, 11, '运营', '传统运营', '初级传统运营', '思优科技有限公司']
# ['吴琳', '男', 2011, 4, '设计', '原画', '初级原画', '天开网络有限公司']
# ['刘瑜', '男', 2014, 9, '设计', '原画', '特聘原画', '四通信息有限公司']
# ['马丽', '男', 2019, 1, '开发', '后端开发', '特聘后端开发', '盟新传媒有限公司']
# ['杨鹏', '女', 2017, 4, '设计', '原画', '中级原画', '浦华众城网络有限公司']
# ['吴莹', '男', 2001, 3, '开发', '前端开发', '高级前端开发', '万迅电脑传媒有限公司']
# ['李桂花', '男', 2007, 11, '开发', '前端开发', '高级前端开发', '毕博诚网络有限公司']
# ['柯琴', '男', 2014, 1, '运维', '服务器管理', '高级服务器管理', '商软冠联科技有限公司']
# ['高玉华', '女', 2014, 5, '财务', '出纳', '特聘出纳', '雨林木风计算机信息有限公司']
# ['马桂芳', '女', 2012, 7, '开发', '后端开发', '高级后端开发', '创亿网络有限公司']
# ['饶想', '男', 2017, 6, '运维', '数据库运维', '特聘数据库运维', '鸿睿思博信息有限公司']
# ['王丹', '男', 2009, 5, '财务', '出纳', '特聘出纳', '富罳信息有限公司']
# ['黄帅', '女', 2019, 11, '财务', '会计', '特聘会计', '恩悌信息有限公司']
# ['黄鹏', '女', 2003, 12, '运维', '数据库运维', '初级数据库运维', '东方峻景网络有限公司']
# ['顾玲', '男', 2004, 12, '测试', '白盒测试', '高级白盒测试', '银嘉信息有限公司']
# ['曹玉珍', '男', 2012, 8, '管理', '技术领导', '高级技术领导', '鸿睿思博信息有限公司']
# ['刘娜', '男', 2018, 10, '管理', '公司领导', '特聘公司领导', '晖来计算机传媒有限公司']
# ['吴小红', '女', 2014, 2, '运营', '传统运营', '初级传统运营', '创联世纪网络有限公司']
# ['韩鑫', '男', 2001, 3, '开发', '前端开发', '特聘前端开发', '维旺明传媒有限公司']
# ['陈倩', '男', 2002, 10, '测试', '白盒测试', '高级白盒测试', '晖来计算机传媒有限公司']
# ['鲁静', '男', 2015, 5, '运维', '数据库运维', '中级数据库运维', '创汇网络有限公司']
# ['舒娟', '女', 2015, 11, '测试', '白盒测试', '初级白盒测试', '国讯网络有限公司']
# ['王云', '男', 2002, 2, '财务', '出纳', '特聘出纳', '创联世纪信息有限公司']
# ['杨刚', '男', 2017, 3, '运营', '传统运营', '初级传统运营', '创汇网络有限公司']
# ['杨华', '男', 2002, 12, '财务', '出纳', '高级出纳', '思优科技有限公司']
# ['殷桂香', '男', 2014, 2, '管理', '技术领导', '特聘技术领导', '联通时科信息有限公司']
# ['刘旭', '女', 2019, 2, '开发', '前端开发', '初级前端开发', '易动力网络有限公司']
# ['李桂英', '女', 2011, 1, '运维', '服务器管理', '中级服务器管理', '昂歌信息传媒有限公司']
# ['潘秀荣', '男', 2005, 9, '运维', '数据库运维', '中级数据库运维', '华成育卓网络有限公司']
# ['祝凯', '女', 2017, 9, '运维', '数据库运维', '特聘数据库运维', '华远软件网络有限公司']
# ['韦宇', '女', 2001, 1, '开发', '后端开发', '中级后端开发', '太极传媒有限公司']
# ['刘楠', '女', 2014, 8, '财务', '出纳', '初级出纳', '趋势科技有限公司']
# ['娄桂芝', '男', 2013, 10, '运维', '服务器管理', '特聘服务器管理', '雨林木风计算机传媒有限公司']
# ['罗晨', '男', 2007, 1, '管理', '公司领导', '中级公司领导', '商软冠联网络有限公司']
# ['李玉梅', '女', 2019, 4, '管理', '公司领导', '中级公司领导', '诺依曼软件传媒有限公司']
# ['李丹', '女', 2003, 3, '管理', '公司领导', '高级公司领导', '黄石金承科技有限公司']
# ['白萍', '女', 2005, 2, '管理', '公司领导', '特聘公司领导', '易动力科技有限公司']
# ['刘梅', '女', 2008, 5, '管理', '技术领导', '初级技术领导', '易动力网络有限公司']
# ['张平', '男', 2003, 3, '开发', '平台开发', '高级平台开发', '黄石金承科技有限公司']
# ['侯秀云', '男', 2002, 10, '测试', '黑盒测试', '高级黑盒测试', '华远软件科技有限公司']
# ['文丽', '女', 2003, 10, '测试', '黑盒测试', '高级黑盒测试', '维涛网络有限公司']
# ['陈淑珍', '男', 2005, 9, '测试', '黑盒测试', '中级黑盒测试', '凌云信息有限公司']
# ['谢勇', '男', 2008, 9, '测试', '黑盒测试', '中级黑盒测试', '晖来计算机传媒有限公司']
# ['张红霞', '女', 2005, 4, '测试', '白盒测试', '初级白盒测试', '合联电子网络有限公司']
# ['赵秀云', '女', 2006, 1, '运营', '传统运营', '中级传统运营', '商软冠联信息有限公司']
# ['张春梅', '男', 2012, 12, '运营', '新媒体运营', '特聘新媒体运营', '彩虹传媒有限公司']
# ['路欣', '女', 2012, 6, '运营', '新媒体运营', '高级新媒体运营', '趋势传媒有限公司']
# ['朱志强', '男', 2005, 7, '管理', '公司领导', '特聘公司领导', '四通网络有限公司']
# ['张秀芳', '男', 2012, 11, '开发', '平台开发', '特聘平台开发', '九方科技有限公司']
# ['黄丽', '女', 2002, 10, '管理', '公司领导', '初级公司领导', '昊嘉科技有限公司']
# ['张勇', '男', 2011, 6, '开发', '平台开发', '中级平台开发', '兰金电子信息有限公司']
# ['杜强', '男', 2007, 7, '运营', '新媒体运营', '高级新媒体运营', '晖来计算机信息有限公司']
# ['周健', '男', 2008, 5, '测试', '白盒测试', '特聘白盒测试', '九方信息有限公司']
# ['郭龙', '女', 2015, 8, '运营', '新媒体运营', '高级新媒体运营', '九方科技有限公司']
# ['邢桂花', '男', 2015, 6, '开发', '平台开发', '高级平台开发', '天益网络有限公司']
# ['张军', '女', 2011, 3, '管理', '技术领导', '特聘技术领导', '飞海科技网络有限公司']
# ['孙红梅', '女', 2015, 6, '运营', '传统运营', '初级传统运营', '万迅电脑网络有限公司']
# ['李杨', '男', 2018, 7, '开发', '平台开发', '特聘平台开发', '良诺网络有限公司']
# ['吴博', '女', 2002, 7, '测试', '黑盒测试', '高级黑盒测试', '明腾传媒有限公司']
# ['胡秀荣', '女', 2007, 11, '管理', '技术领导', '初级技术领导', '易动力科技有限公司']
# ['林成', '男', 2011, 7, '设计', '原画', '高级原画', '四通传媒有限公司']
# ['严梅', '女', 2008, 7, '设计', '原画', '中级原画', '创亿信息有限公司']
# ['陈倩', '女', 2003, 1, '开发', '平台开发', '特聘平台开发', '联软信息有限公司']
# ['吴鹏', '男', 2008, 11, '开发', '后端开发', '中级后端开发', '同兴万点科技有限公司']
# ['赵璐', '女', 2009, 3, '运营', '新媒体运营', '特聘新媒体运营', '襄樊地球村传媒有限公司']
# ['王洋', '男', 2013, 8, '财务', '出纳', '初级出纳', '襄樊地球村信息有限公司']
# ['郭艳', '男', 2009, 3, '测试', '白盒测试', '特聘白盒测试', '易动力科技有限公司']
# ['陈志强', '男', 2004, 6, '设计', '插画', '特聘插画', '维涛科技有限公司']
# ['萧丹', '男', 2004, 1, '运营', '新媒体运营', '初级新媒体运营', '时空盒数字网络有限公司']
# ['梁宁', '男', 2011, 10, '财务', '出纳', '高级出纳', '浙大万朋网络有限公司']
# ['刘桂香', '女', 2002, 7, '财务', '出纳', '初级出纳', '通际名联传媒有限公司']
# ['张冬梅', '男', 2002, 11, '运维', '服务器管理', '初级服务器管理', '鸿睿思博科技有限公司']
# ['王燕', '男', 2018, 12, '测试', '白盒测试', '初级白盒测试', '时空盒数字科技有限公司']
# ['冯丹丹', '女', 2016, 2, '运维', '服务器管理', '中级服务器管理', '立信电子科技有限公司']
# ['赵娟', '女', 2005, 6, '运维', '数据库运维', '特聘数据库运维', '四通网络有限公司']
# ['朱淑兰', '男', 2007, 6, '设计', '插画', '高级插画', '中建创业传媒有限公司']
# ['张斌', '男', 2018, 2, '测试', '白盒测试', '高级白盒测试', '时刻科技有限公司']
# ['段丹', '男', 2019, 1, '测试', '黑盒测试', '初级黑盒测试', 'MBP软件网络有限公司']
# ['潘玉英', '男', 2004, 4, '测试', '白盒测试', '中级白盒测试', '华成育卓信息有限公司']
# ['马丹', '男', 2003, 7, '测试', '黑盒测试', '特聘黑盒测试', '快讯网络有限公司']
# ['杨帆', '女', 2004, 1, '测试', '黑盒测试', '初级黑盒测试', '思优网络有限公司']
# ['陈宁', '女', 2009, 10, '设计', '原画', '初级原画', '双敏电子传媒有限公司']
# ['高宇', '女', 2005, 12, '设计', '原画', '特聘原画', '明腾传媒有限公司']
# ['马丹丹', '男', 2005, 4, '测试', '黑盒测试', '中级黑盒测试', '兰金电子信息有限公司']
# ['雷海燕', '男', 2013, 3, '管理', '公司领导', '高级公司领导', '趋势信息有限公司']
# ['陆建', '女', 2002, 3, '设计', '插画', '中级插画', '图龙信息科技有限公司']
# ['汪刚', '女', 2002, 5, '运营', '传统运营', '特聘传统运营', '群英信息有限公司']
# ['胡淑英', '女', 2008, 12, '管理', '技术领导', '初级技术领导', '思优科技有限公司']
# ['郭建', '女', 2002, 10, '测试', '白盒测试', '特聘白盒测试', '时空盒数字网络有限公司']
# ['唐丽华', '女', 2007, 11, '管理', '技术领导', '特聘技术领导', '立信电子网络有限公司']
# ['董海燕', '男', 2001, 11, '管理', '技术领导', '初级技术领导', '维旺明传媒有限公司']
# ['郑建国', '女', 2005, 8, '开发', '平台开发', '中级平台开发', '天开传媒有限公司']
# ['周淑华', '女', 2015, 9, '财务', '会计', '初级会计', '天开网络有限公司']
# ['张琴', '男', 2004, 12, '运营', '传统运营', '初级传统运营', '戴硕电子传媒有限公司']
# ['谭玉梅', '男', 2009, 6, '测试', '白盒测试', '中级白盒测试', '南康信息有限公司']
# ['赵建', '男', 2002, 6, '测试', '黑盒测试', '中级黑盒测试', '维旺明传媒有限公司']
# ['傅敏', '男', 2018, 1, '运营', '传统运营', '特聘传统运营', '鸿睿思博信息有限公司']
# ['高红霞', '男', 2015, 1, '设计', '插画', '高级插画', '菊风公司网络有限公司']
# ['王洋', '男', 2011, 3, '运维', '服务器管理', '特聘服务器管理', '凌云传媒有限公司']
# ['黄旭', '男', 2012, 10, '运营', '新媒体运营', '特聘新媒体运营', '创亿科技有限公司']
# ['杨丹丹', '男', 2006, 9, '开发', '平台开发', '初级平台开发', '时空盒数字信息有限公司']
# ['程晨', '男', 2002, 12, '管理', '技术领导', '高级技术领导', '网新恒天网络有限公司']
# ['蔡鑫', '女', 2016, 6, '运营', '传统运营', '中级传统运营', '新格林耐特网络有限公司']
# ['钱利', '男', 2007, 7, '财务', '会计', '特聘会计', '盟新科技有限公司']
# ['蒲颖', '男', 2003, 10, '运营', '新媒体运营', '中级新媒体运营', '维涛信息有限公司']
# ['束玉华', '女', 2012, 3, '测试', '白盒测试', '中级白盒测试', '易动力信息有限公司']
# ['朱红霞', '女', 2017, 6, '运维', '服务器管理', '特聘服务器管理', '万迅电脑科技有限公司']
# ['贾岩', '男', 2019, 7, '测试', '白盒测试', '高级白盒测试', '黄石金承传媒有限公司']
# ['张亮', '女', 2019, 4, '财务', '会计', '初级会计', '信诚致远科技有限公司']
# ['吴峰', '男', 2008, 6, '开发', '前端开发', '高级前端开发', '彩虹网络有限公司']
# ['黄强', '女', 2019, 6, '测试', '白盒测试', '高级白盒测试', '华成育卓网络有限公司']
# ['唐玉兰', '男', 2016, 9, '设计', '插画', '初级插画', '开发区世创传媒有限公司']
# ['高洁', '男', 2002, 2, '财务', '会计', '特聘会计', '新宇龙信息信息有限公司']
# ['张秀荣', '女', 2014, 8, '运维', '数据库运维', '高级数据库运维', '黄石金承网络有限公司']
# ['赵燕', '男', 2007, 2, '财务', '会计', '中级会计', '雨林木风计算机科技有限公司']
# ['李金凤', '女', 2005, 3, '运维', '数据库运维', '初级数据库运维', '趋势网络有限公司']
# ['黄刚', '男', 2002, 3, '财务', '会计', '高级会计', '商软冠联传媒有限公司']
# ['蓝玉兰', '女', 2006, 10, '运维', '数据库运维', '初级数据库运维', '毕博诚网络有限公司']
# ['甄婷婷', '女', 2019, 11, '财务', '会计', '初级会计', '华远软件信息有限公司']
# ['龙秀梅', '女', 2016, 2, '运营', '新媒体运营', '特聘新媒体运营', '双敏电子科技有限公司']
# ['黄红霞', '男', 2014, 7, '管理', '公司领导', '中级公司领导', '戴硕电子传媒有限公司']
# ['范鹏', '女', 2009, 7, '运营', '传统运营', '高级传统运营', '图龙信息科技有限公司']
# ['李桂芳', '男', 2005, 8, '运维', '服务器管理', '高级服务器管理', '易动力网络有限公司']
# ['胡玉', '男', 2013, 8, '设计', '原画', '中级原画', '凌颖信息科技有限公司']
# ['曹晶', '女', 2013, 11, '运营', '新媒体运营', '初级新媒体运营', '创汇科技有限公司']
# ['李平', '男', 2013, 7, '运维', '服务器管理', '高级服务器管理', '网新恒天信息有限公司']
# ['胡颖', '男', 2014, 10, '设计', '插画', '中级插画', '同兴万点信息有限公司']
# ['崔金凤', '女', 2009, 4, '运维', '服务器管理', '初级服务器管理', '昂歌信息网络有限公司']
# ['李畅', '女', 2013, 1, '运维', '服务器管理', '初级服务器管理', '四通网络有限公司']
# ['刘建华', '女', 2009, 12, '测试', '白盒测试', '高级白盒测试', '晖来计算机网络有限公司']
# ['吴彬', '女', 2005, 2, '管理', '公司领导', '特聘公司领导', '七喜网络有限公司']
# ['廖婷婷', '女', 2004, 2, '测试', '白盒测试', '中级白盒测试', '合联电子传媒有限公司']
# ['张玉华', '男', 2009, 10, '管理', '技术领导', '特聘技术领导', '易动力传媒有限公司']
# ['孙佳', '男', 2004, 2, '测试', '白盒测试', '初级白盒测试', '良诺传媒有限公司']
# ['李楠', '男', 2008, 1, '测试', '白盒测试', '高级白盒测试', '数字100信息有限公司']
# ['史浩', '女', 2017, 7, '财务', '出纳', '中级出纳', '开发区世创科技有限公司']
# ['张坤', '女', 2011, 5, '设计', '原画', '特聘原画', '新格林耐特科技有限公司']
# ['李浩', '女', 2017, 10, '开发', '前端开发', '初级前端开发', '戴硕电子网络有限公司']
# ['王瑞', '女', 2016, 5, '设计', '插画', '初级插画', '良诺传媒有限公司']
# ['李丹丹', '男', 2006, 1, '测试', '白盒测试', '高级白盒测试', '开发区世创网络有限公司']
# ['赵兵', '女', 2011, 5, '管理', '技术领导', '中级技术领导', '佳禾网络有限公司']
# ['王桂芝', '男', 2010, 9, '运营', '新媒体运营', '高级新媒体运营', '济南亿次元传媒有限公司']
# ['蒋金凤', '男', 2003, 8, '运维', '服务器管理', '高级服务器管理', '思优传媒有限公司']
# ['高坤', '男', 2019, 5, '测试', '黑盒测试', '初级黑盒测试', '华泰通安传媒有限公司']
# ['游玉珍', '男', 2017, 9, '开发', '前端开发', '特聘前端开发', '易动力网络有限公司']
# ['唐磊', '女', 2008, 12, '运维', '数据库运维', '高级数据库运维', '商软冠联网络有限公司']
# ['杨俊', '女', 2016, 10, '测试', '白盒测试', '高级白盒测试', '鑫博腾飞信息有限公司']
# ['丁荣', '男', 2005, 11, '运维', '服务器管理', '中级服务器管理', '太极信息有限公司']
# ['毛丽丽', '男', 2006, 8, '设计', '原画', '中级原画', '富罳科技有限公司']
# ['郭桂花', '男', 2006, 7, '财务', '会计', '特聘会计', '和泰信息有限公司']
# ['王慧', '男', 2010, 10, '管理', '技术领导', '高级技术领导', '泰麒麟信息有限公司']
# ['卜凤英', '男', 2013, 5, '设计', '插画', '特聘插画', '双敏电子网络有限公司']
# ['包金凤', '男', 2017, 7, '管理', '技术领导', '特聘技术领导', '时刻传媒有限公司']
# ['沙丽', '男', 2012, 11, '管理', '技术领导', '中级技术领导', '恩悌网络有限公司']
# ['吴玉梅', '男', 2014, 2, '开发', '前端开发', '中级前端开发', '四通信息有限公司']
# ['罗娟', '女', 2011, 12, '财务', '会计', '特聘会计', '四通网络有限公司']

# %%
wb.close()
