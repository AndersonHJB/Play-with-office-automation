# %%
import pandas as pd

# %%
df_xlsx = pd.read_excel('ten-thousand.xlsx')
df_json = pd.read_json('ten-thousand.json')

# %%
print(type(df_xlsx))
print(df_xlsx)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      name gender  join-year  join-month department    job job-name  \
# 0     黄婷婷      女       2005          12         开发   平台开发   中级平台开发
# 1     梁桂兰      女       2005           8         财务     会计     初级会计
# 2     刘秀云      男       2017           3         设计     插画     中级插画
# 3     王建军      女       2015           6         运维  服务器管理  特聘服务器管理
# 4      刘璐      男       2013           3         管理   公司领导   特聘公司领导
# 5      程敏      男       2005           4         运营  新媒体运营  特聘新媒体运营
# 6     吴淑英      女       2007           8         财务     出纳     中级出纳
# 7     李玉兰      女       2005          10         设计     原画     中级原画
# 8      沈丽      女       2008           7         管理   公司领导   高级公司领导
# 9      杨刚      男       2016           2         开发   平台开发   初级平台开发
# 10     符鹏      男       2001          12         运维  数据库运维  高级数据库运维
# 11     吕宇      男       2007           8         开发   平台开发   特聘平台开发
# ...

# %%
print(type(df_json))
print(df_json)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#             company department gender    job job-name  join-month  join-year  \
# 0     雨林木风计算机信息有限公司         开发      女   平台开发   中级平台开发          12       2005
# 1       数字100科技有限公司         财务      女     会计     初级会计           8       2005
# 10         快讯网络有限公司         运维      男  数据库运维  高级数据库运维          12       2001
# 100      双敏电子信息有限公司         运维      女  数据库运维  中级数据库运维           1       2016
# 1000       富罳信息有限公司         测试      女   白盒测试   高级白盒测试           9       2015
# 1001    诺依曼软件传媒有限公司         测试      男   黑盒测试   初级黑盒测试           8       2011
# 1002     华远软件科技有限公司         财务      女     会计     高级会计           5       2017
# 1003       四通科技有限公司         运维      男  服务器管理  高级服务器管理           1       2012
# 1004    济南亿次元科技有限公司         运营      男   传统运营   高级传统运营           8       2011
# 1005     立信电子信息有限公司         测试      男   黑盒测试   初级黑盒测试           9       2019
# 1006       良诺传媒有限公司         运维      男  服务器管理  初级服务器管理          10       2014
# ...

# %%
df_xlsx.to_csv('ten-thousand.csv')

# %%
df_json.to_html('ten-thousand.html')

# %% [markdown]
# ## Pandas所有的数据读取函数
#
# - pd.read_clipboard
# - pd.read_csv
# - pd.read_excel
# - pd.read_feather
# - pd.read_fwf
# - pd.read_gbq
# - pd.read_hdf
# - pd.read_html
# - pd.read_json
# - pd.read_msgpack
# - pd.read_pickle
# - pd.read_sas
# - pd.read_sql
# - pd.read_sql_query
# - pd.read_sql_table
# - pd.read_stata
# - pd.read_table

# %% [markdown]
# ## Pandas所有的导出函数
#
# - df_xlsx.to_clipboard
# - df_xlsx.to_csv
# - df_xlsx.to_dense
# - df_xlsx.to_dict
# - df_xlsx.to_feather
# - df_xlsx.to_gbq
# - df_xlsx.to_hdf
# - df_xlsx.to_html
# - df_xlsx.to_json
# - df_xlsx.to_latex
# - df_xlsx.to_msgpack
# - df_xlsx.to_panel
# - df_xlsx.to_period
# - df_xlsx.to_pickle
# - df_xlsx.to_records
# - df_xlsx.to_sparse
# - df_xlsx.to_sql
# - df_xlsx.to_stata
# - df_xlsx.to_string
# - df_xlsx.to_timestamp
# - df_xlsx.to_xarray
